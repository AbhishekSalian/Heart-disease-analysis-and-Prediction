# %% [markdown]
# <h1> Heart Diease </h1>

# %% [markdown]
# ![image](https://miro.medium.com/max/4800/1*ooqlgirGtghlYIw0ujnBkA.jpeg)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns
style.use('ggplot')

# %%
df = pd.read_csv("../input/heart-disease-uci//heart.csv") # data loading into dataframe

# %% [markdown]
# ## Columns

# %% [markdown]
# * age
# * sex
# * chest pain type (4 values)
# * resting blood pressure
# * serum cholestoral in mg/dl
# * fasting blood sugar > 120 mg/dl
# * resting electrocardiographic results (values 0,1,2)
# * maximum heart rate achieved
# * exercise induced angina
# * oldpeak = ST depression induced by exercise relative to rest
# * the slope of the peak exercise ST segment
# * number of major vessels (0-3) colored by flourosopy
# * thal: 3 = normal; 6 = fixed defect; 7 = reversable defect

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
df.isna().sum() # output of this  indicate that there is no missing values in any column
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
cols = df.columns
cols
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %% [markdown]
# # Columnwise Analysis

# %% [markdown]
# ## AGE

# %%
max_age = max(df['age'])
min_age = min(df['age'])
print(f"Max age {max_age}, min age {min_age}")
# Out:
# Max age 77, min age 29

# %%
plt.figure(figsize = (12,6))
age_count = dict(df['age'].value_counts())
plt.bar(age_count.keys(),age_count.values(),width = 0.5)
plt.xticks(ticks=[i for i in range(min_age-1,max_age+1)])
plt.title("Age frequency plot")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# * Age 55 yrs has highest frequency
# * Age 29,74,76,77 has lowest frequency
# * Seems to be a bimodal case

# %% [markdown]
# ## SEX

# %%
plt.figure(figsize = (5,5))
sex_count = dict(df['sex'].value_counts())
plt.bar(sex_count.keys(),sex_count.values(),width = 0.5)
plt.xticks([0,1],("Female(0)","Male(1)"))
plt.xlabel("Sex")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# * No.of males samples in data is more than female.
# * We cannot conclude that men has more chances of getting heart diease than women since it is just a frequency plot which means suppose more females were tested more samples would have there.

# %% [markdown]
# ## Chest pain

# %% [markdown]
# * Value 1: typical angina
# * Value 2: atypical angina
# * Value 3: non-anginal pain
# * Value 4: asymptomatic

# %%
plt.figure(figsize = (5,5))
count = dict(df['cp'].value_counts())
plt.bar(count.keys(),count.values(),width = 0.5)
plt.xticks([0,1,2,3],("typical angina","Atypical angina","Non-anginal pain","Asymtomatic"),rotation=45)
plt.title("Chest pain frequency plot")
plt.xlabel("Chest pain type")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# * Chest pain of type 0 is more than any other type

# %% [markdown]
# ## Resting blood pressure

# %%
plt.figure(figsize = (10,8))
count = dict(df['trestbps'].value_counts())
plt.bar(count.keys(),count.values(),width = 0.7)
#plt.xticks(ticks=[i for i in range(min(df['trestbps'])-1,max(df['trestbps'])+1)])
plt.title("resting blood pressure frequency plot")
plt.xlabel("resting blood pressure in mm")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ## Serum cholestoral

# %%
plt.figure(figsize = (8,5))
count = dict(df['chol'].value_counts())
plt.bar(count.keys(),count.values(),width = 1,color='red')
#plt.xticks(ticks=[i for i in range(min(df['trestbps'])-1,max(df['trestbps'])+1)])
plt.title("serum cholestoral in mg/dl plot")
plt.xlabel("serum cholestoral in mg/dl")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ## Fasting blood sugar

# %%
plt.figure(figsize = (5,5))
count = dict(df['fbs'].value_counts())
plt.bar(count.keys(),count.values(),width = 0.6)
plt.xticks([0,1],("False(0)","True(1)"))
plt.title("Fasting blood sugar plot")
plt.xlabel("Fasting blood sugar > 120 mg/dl")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ## Resting electrocardiographic results

# %% [markdown]
# Resting electrocardiographic results
# * Value 0: normal
# * Value 1: having ST-T wave abnormality (T wave inversions and/or ST elevation or depression of > 0.05 mV)
# * Value 2: showing probable or definite left ventricular hypertrophy by Estes' criteria

# %%
plt.figure(figsize = (5,5))
count = dict(df['restecg'].value_counts())
plt.bar(count.keys(),count.values(),width = 0.6)
plt.xticks([0,1,2])
plt.title("Resting electrocardiographic results plot")
plt.xlabel("Resting electrocardiographic value")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ## Maximum heart rate achieved

# %%
plt.figure(figsize = (32,10))
count = dict(df['thalach'].value_counts())
plt.bar(count.keys(),count.values(),width = 0.6)
plt.xticks(ticks= list(count.keys()),rotation=90)
plt.title("Maximum heart rate achieved plot")
plt.xlabel("Maximum heart rate achieved")
plt.ylabel("Frequency")
plt.show()

# %%
sns.distplot(df['thalach'])
plt.show()

# %% [markdown]
# ## Exercise induced angina

# %%
plt.figure(figsize = (5,5))
count = dict(df['exang'].value_counts())
plt.bar(count.keys(),count.values(),width = 0.6)
plt.xticks(ticks= list(count.keys()),labels=["NO(0)","YES(1)"])
plt.title("Exercise induced angina plot")
plt.xlabel("Exercise induced angina")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ## ST depression induced by exercise relative to rest

# %%
plt.figure(figsize = (20,8))
count = dict(df['oldpeak'].value_counts())
plt.bar(count.keys(),count.values(),width = 0.08)
plt.xticks(ticks= list(count.keys()))
plt.title("ST depression induced by exercise plot")
plt.xlabel("ST depression induced by exercise relative to rest")
plt.ylabel("Frequency")
plt.show()

# %%
sns.distplot(df['oldpeak'])
plt.show()

# %% [markdown]
# ## Slope of the peak exercise ST segment

# %% [markdown]
# The slope of the peak exercise ST segment
# * Value 1: upsloping
# * Value 2: flat
# * Value 3: downsloping

# %%
plt.figure(figsize = (5,5))
count = dict(df['slope'].value_counts())
plt.bar(count.keys(),count.values(),width = 0.8)
plt.xticks(ticks= list(count.keys()))
plt.title("The slope of the peak exercise plot")
plt.xlabel("The slope of the peak exercise ST segment")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ## Number of major vessels

# %%
plt.figure(figsize = (5,5))
count = dict(df['ca'].value_counts())
plt.bar(count.keys(),count.values(),width = 0.8)
plt.xticks(ticks= list(count.keys()))
plt.title("Number of major vessels frequency plot")
plt.xlabel("Number of major vessels (0-3) colored by flourosopy")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ## Thal

# %% [markdown]
# 3 = normal; 6 = fixed defect; 7 = reversable defect

# %%
plt.figure(figsize = (5,5))
count = dict(df['thal'].value_counts())
plt.bar(count.keys(),count.values(),width = 0.8)
plt.xticks(ticks= list(count.keys()))
plt.title("Thal plot")
plt.xlabel("Thal")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ## Target

# %%
plt.figure(figsize = (5,5))
count = dict(df['target'].value_counts())
plt.bar(count.keys(),count.values(),width = 0.8)
plt.xticks(ticks= list(count.keys()))
plt.title("Target plot")
plt.xlabel("Target")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# # Correlation map

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_e6a0e68e_6a93_11ea_a9e1_6396a2976ed8row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_e6a0e68e_6a93_11ea_a9e1_6396a2976ed8row0_col1 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_e6a0e68e_6a93_11ea_a9e1_6396a2976ed8row0_col2 {
#             background-color:  #86a9fc;
#             color:  #000000;
#         }    #T_e6a0e68e_6a93_11ea_a9e1_6396a2976ed8row0_col3 {
#             background-color:  #b6cefa;
#             color:  #000000;
#         }    #T_e6a0e68e_6a93_11ea_a9e1_6396a2976ed8row0_col4 {
#             background-color:  #adc9fd;
#             color:  #000000;
#         }    #T_e6a0e68e_6a93_11ea_a9e1_6396a2976ed8row0_col5 {
#             background-color:  #779af7;
#             color:  #000000;
#         }    #T_e6a0e68e_6a93_11ea_a9e1_6396a2976ed8row0_col6 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_e6a0e68e_6a93_11ea_a9e1_6396a2976ed8row0_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_e6a0e68e_6a93_11ea_a9e1_6396a2976ed8row0_col8 {
#             background-color:  #b7cff9;
#             color:  #000000;
#         }    #T_e6a0e68e_6a93_11ea_a9e1_6396a2976ed8row0_col9 {
#             background-color:  #dcdddd;
#             color:  #000000;
#         }    #T_e6a0e68e_6a93_11ea_a9e1_6396a2976ed8row0_col10 {
#             background-color:  #90b2fe;
#             color:  #000000;
#         }    #T_e6a0e68e_6a93_11ea_a9e1_6396a2976ed8row0_col11 {
#             background-color:  #d7dce3;
#             color:  #000000;
#         }    #T_e6a0e68e_6a93_11ea_a9e1_6396a2976ed8row0_col12 {
#             background-color:  #a1c0ff;
#             color:  #000000;
#         }    #T_e6a0e68e_6a93_11ea_a9e1_6396a2976ed8row0_col13 {
#             background-color:  #688aef;
#             color:  #000000;
#         }    #T_e6a0e68e_6a93_11ea_a9e1_6396a2976ed8row1_col0 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_e6a0e68e_6a93_11ea_a9e1_6396a2976ed8row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_e6a0e68e_6a93_11ea_a9e1_6396a2976ed8row1_col2 {
#             background-color:  #8caffe;
#             color:  #000000;
#         }    #T_e6a0e68e_6a93_11ea_a9e1_6396a2976ed8row1_col3 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_e6a0e68e_6a93_11ea_a9e1_6396a2976ed8row1_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_e6a0e68e_6a93_11ea_a9e1_6396a2976ed8row1_col5 {
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }    #T_e6a0e68e_6a93_11ea_a9e1_6396a2976ed8row1_col6 {
#             background-color:  #536edd;
#             color:  #000000;
#         }    #T_e6a0e68e_6a93_11ea_a9e1_6396a2976ed8row1_col7 {
#             background-color:  #8db0fe;
#             color:  #000000;
#         }    #T_e6a0e68e_6a93_11ea_a9e1_6396a2976ed8row1_col8 {
#             background-color:  #c1d4f4;
#             color:  #000000;
#         }    #T_e6a0e68e_6a93_11ea_a9e1_6396a2976ed8row1_col9 {
#             background-color:  #c9d7f0;
#             color:  #000000;
#         }    #T_e6a0e68e_6a93_11ea_a9e1_6396a2976ed8row1_col10 {
#             background-color:  #aec9fc;
#             color:  #000000;
#         }    #T_e6a0e68e_6a93_11ea_a9e1_6396a2976ed8row1_col11 {
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }    #T_e6a0e68e_6a93_11ea_a9e1_6396a2976ed8row1_col12 {
#             background-color:  #c4d5f3;
#             color:  #000000;
#         }    #T_e6a0e68e_6a93_11ea_a9e1_6396a2976ed8row1_col13 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }    #T_e6a0e68e_6a93_11ea_a9e1_6396a2976ed8row2_col0 {
#             background-color:  #88abfd;
#             color:  #000000;
#         }    #T_e6a0e68e_6a93_11ea_a9e1_6396a2976ed8row2_col1 {
#             background-color:  #7597f6;
#             color:  #000000;
#         }    #T_e6a0e68e_6a93_11ea_a9e1_6396a2976ed8row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_e6a0e68e_6a93_11ea_a9e1_6396a2976ed8row2_col3 {
#             background-color:  #7093f3;
#             color:  #000000;
#         }    #T_e6a0e68e_6a93_11ea_a9e1_6396a2976ed8row2_col4 {
#             background-color:  #5977e3;
#             color:  #000000;
#         }    #T_e6a0e68e_6a93_11ea_a9e1_6396a2976ed8row2_col5 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_e6a0e68e_6a93_11ea_a9e1_6396a2976ed8row2_col6 {
#             background-color:  #7093f3;
#             color:  #000000;
#         }    #T_e6a0e68e_6a93_11ea_a9e1_6396a2976ed8row2_col7 {
#             background-color:  #dcdddd;
#             color:  #000000;
#         }    #T_e6a0e68e_6a93_11ea_a9e1_6396a2976ed8row2_col8 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_e6a0e68e_6a93_11ea_a9e1_6396a2976ed8row2_col9 {
#             background-color:  #94b6ff;
#             color:  #000000;
#         }    #T_e6a0e68e_6a93_11ea_a9e1_6396a2976ed8row2_col10 {
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }    #T_e6a0e68e_6a93_11ea_a9e1_6396a2976ed8row2_col11 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_e6a0e68e_6a93_11ea_a9e1_6396a2976ed8row2_col12 {
#             background-color:  #6485ec;
#             color:  #000000;
#         }    #T_e6a0e68e_6a93_11ea_a9e1_6396a2976ed8row2_col13 {
#             background-color:  #f2c9b4;
#             color:  #000000;
#         }    #T_e6a0e68e_6a93_11ea_a9e1_6396a2976ed8row3_col0 {
#             background-color:  #d9dce1;
#             color:  #000000;
#         }    #T_e6a0e68e_6a93_11ea_a9e1_6396a2976ed8row3_col1 {
#             background-color:  #7295f4;
#             color:  #000000;
#         }    #T_e6a0e68e_6a93_11ea_a9e1_6396a2976ed8row3_col2 {
#             background-color:  #a5c3fe;
#             color:  #000000;
#         }    #T_e6a0e68e_6a93_11ea_a9e1_6396a2976ed8row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_e6a0e68e_6a93_11ea_a9e1_6396a2976ed8row3_col4 {
#             background-color:  #93b5fe;
#             color:  #000000;
#         }    #T_e6a0e68e_6a93_11ea_a9e1_6396a2976ed8row3_col5 {
#             background-color:  #89acfd;
#             color:  #000000;
#         }    #T_e6a0e68e_6a93_11ea_a9e1_6396a2976ed8row3_col6 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_e6a0e68e_6a93_11ea_a9e1_6396a2976ed8row3_col7 {
#             background-color:  #8db0fe;
#             color:  #000000;
#         }    #T_e6a0e68e_6a93_11ea_a9e1_6396a2976ed8row3_col8 {
#             background-color:  #afcafc;
#             color:  #000000;
#         }    #T_e6a0e68e_6a93_11ea_a9e1_6396a2976ed8row3_col9 {
#             background-color:  #dadce0;
#             color:  #000000;
#         }    #T_e6a0e68e_6a93_11ea_a9e1_6396a2976ed8row3_col10 {
#             background-color:  #9bbcff;
#             color:  #000000;
#         }    #T_e6a0e68e_6a93_11ea_a9e1_6396a2976ed8row3_col11 {
#             background-color:  #b1cbfc;
#             color:  #000000;
#         }    #T_e6a0e68e_6a93_11ea_a9e1_6396a2976ed8row3_col12 {
#             background-color:  #9fbfff;
#             color:  #000000;
#         }    #T_e6a0e68e_6a93_11ea_a9e1_6396a2976ed8row3_col13 {
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }    #T_e6a0e68e_6a93_11ea_a9e1_6396a2976ed8row4_col0 {
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }    #T_e6a0e68e_6a93_11ea_a9e1_6396a2976ed8row4_col1 {
#             background-color:  #4e68d8;
#             color:  #000000;
#         }    #T_e6a0e68e_6a93_11ea_a9e1_6396a2976ed8row4_col2 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_e6a0e68e_6a93_11ea_a9e1_6396a2976ed8row4_col3 {
#             background-color:  #86a9fc;
#             colo

# %% [markdown]
# * No two features are highly correlated

# %% [markdown]
# # Targetwise Analysis

# %%
tar1_df = df[df['target']==1]
tar0_df = df[df['target']==0]

# %%
print("No. of samples where target==1 (Yes heart disease):",len(tar1_df))
print("No. of samples where target==0 (No heart disease):",len(tar0_df))
# Out:
# No. of samples where target==1 (Yes heart disease): 165
# No. of samples where target==0 (No heart disease): 138

# %% [markdown]
# ## Target, age

# %%
total1 = sum(list(tar1_df['age'].value_counts())) # target == 1 
total0 = sum(list(tar0_df['age'].value_counts())) # target == 0

print(f"Target 1: {total1} | Target 0: {total0}")
# Out:
# Target 1: 165 | Target 0: 138

# %%
d = dict(tar1_df['age'].value_counts())
plt.figure(figsize=(13,7))
plt.bar(x =list(d.keys()),height = list(d.values()))
plt.xticks(list(d.keys()))
plt.xlabel("Age")
plt.ylabel("#people")
plt.title("Target=1 vs Age")
plt.show()

# %%
d = dict(tar0_df['age'].value_counts())
plt.figure(figsize=(13,7))
plt.bar(x =list(d.keys()),height = list(d.values()))
plt.xticks(list(d.keys()))
plt.xlabel("Age")
plt.ylabel("#people")
plt.title("Target=0 vs Age")
plt.show()

# %% [markdown]
# ## Target *vs* sex

# %%
tar1_df['sex'].value_counts() # target == 1 , male = 1 and female = 0
# Out:
# 1    93
# 0    72
# Name: sex, dtype: int64

# %%
tar0_df['sex'].value_counts() # target == 0  , male = 1 and female = 0
# Out:
# 1    114
# 0     24
# Name: sex, dtype: int64

# %%
male = tar1_df['sex'].value_counts()[1]
female = tar1_df['sex'].value_counts()[0]

print(f'No. of male with heart diease:{male}\nNo. of with female heart disease:{female}\n')

print(f'% of male with heart disease = {round(male/(male+female)*100,2)} %')

print(f'% of female with heart disease = {round(female/(male+female)*100,2)} %')
# Out:
# No. of male with heart diease:93
# No. of with female heart disease:72
#
# % of male with heart disease = 56.36 %
# % of female with heart disease = 43.64 %

# %%
male = tar0_df['sex'].value_counts()[1]
female = tar0_df['sex'].value_counts()[0]

print(f'No. of male with no heart diease:{male}\nNo. of with female no heart disease:{female}\n')

print(f'% of male with no heart disease = {round(male/(male+female)*100,2)} %')

print(f'% of female with no heart disease = {round(female/(male+female)*100,2)} %')
# Out:
# No. of male with no heart diease:114
# No. of with female no heart disease:24
#
# % of male with no heart disease = 82.61 %
# % of female with no heart disease = 17.39 %

# %% [markdown]
# ## Chest pain *vs* Target

# %%
d1 = dict(tar1_df["cp"].value_counts().sort_index())
d0 = dict(tar0_df["cp"].value_counts().sort_index())
plt.figure(1)
plt.subplot(121)
plt.bar(np.array(list(d1.keys())), np.array(list(d1.values())))
plt.xlabel("Chest pain type")
plt.title("Target=1")
plt.subplot(122)
plt.bar(np.array(list(d0.keys())), np.array(list(d0.values())))
plt.xlabel("Chest pain type")
plt.title("Target=0")
plt.show()

# %%
for key in d1:
    print(f"Chest pain of type {key} for target 1 is {round((d1[key]/sum(list(d1.values())))*100,2)} %")
    print(f"Chest pain of type {key} for target 0 is {round((d1[key]/sum(list(d0.values())))*100,2)} %")
    print("--------------------------------------------------------------------------------------------------------------------")
# Out:
# Chest pain of type 0 for target 1 is 23.64 %
# Chest pain of type 0 for target 0 is 28.26 %
# --------------------------------------------------------------------------------------------------------------------
# Chest pain of type 1 for target 1 is 24.85 %
# Chest pain of type 1 for target 0 is 29.71 %
# --------------------------------------------------------------------------------------------------------------------
# Chest pain of type 2 for target 1 is 41.82 %
# Chest pain of type 2 for target 0 is 50.0 %
# --------------------------------------------------------------------------------------------------------------------
# Chest pain of type 3 for target 1 is 9.7 %
# Chest pain of type 3 for target 0 is 11.59 %
# --------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# * As we can see there is no major difference to have a heart disease but majorly we can say CP type 2 is 50 % times fatal

# %% [markdown]
# # Train,test data preparation

# %%
from sklearn.model_selection import train_test_split

# %%
random_state = 42
test_size = 0.2
shuffle = True

# %%
X = df[cols[:-1]].values
Y = df[cols[-1]].values

X_train, X_test,y_train, y_test = train_test_split(X, Y,
                                                   test_size = test_size,
                                                   shuffle = shuffle,
                                                   random_state = random_state)

#y_train = y_train.reshape((y_train.shape[0],1))
#y_test = y_test.reshape((y_test.shape[0],1))

print(f"Training X shape : {X_train.shape}")
print(f"Training y shape : {y_train.shape} \n")
print(f"Testing X shape : {X_test.shape}")
print(f"Testing y shape : {y_test.shape}")
# Out:
# Training X shape : (242, 13)
# Training y shape : (242,)
#
# Testing X shape : (61, 13)
# Testing y shape : (61,)

# %%
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
max_iter =100

# %%
logReg_clf = LogisticRegression(tol = 0.0001,
                                C = 1.0,
                                random_state = random_state,
                                solver = 'lbfgs',
                                max_iter = max_iter,
                                verbose = 0,
                                n_jobs = 5)

# training
logReg_clf.fit(X_train, y_train)

#testing
y_pred = logReg_clf.predict(X_test)

score = accuracy_score(y_test, y_pred)
print("Accuracy of logistic regression classifier is",score*100,"%")
# Out:
# Accuracy of logistic regression classifier is 88.52459016393442 %

# %% [markdown]
# # Support Vector Machine

# %%
from sklearn import svm

# %%
# defining parameter range 
param_grid = {'C': [0.1, 1, 10, 100, 1000],  
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001], 
              'kernel': ['rbf']}  
  
grid1 = GridSearchCV(svm.SVC(random_state = random_state),
                    param_grid,
                    refit = True,
                    verbose = 3) 
  
# fitting the model for grid
grid1.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.551, total=   0.0s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.551, total=   0.0s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.562, total=   0.0s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.542, total=   0.0s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.542, total=   0.0s
# [CV] C=0.1, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=0.1, gamma=0.1, kernel=rbf, score=0.551, total=   0.0s
# [CV] C=0.1, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=0.1, gamma=0.1, kernel=rbf, score=0.551, total=   0.0s
# [CV] C=0.1, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=0.1, gamma=0.1, kernel=rbf, score=0.562, total=   0.0s
# [CV] C=0.1, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=0.1, gamma=0.1, kernel=rbf, score=0.542, total=   0.0s
# [CV] C=0.1, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=0.1, gamma=0.1, kernel=rbf, score=0.542, total=   0.0s
# [CV] C=0.1, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=0.1, gamma=0.01, kernel=rbf, score=0.551, total=   0.0s
# [CV] C=0.1, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=0.1, gamma=0.01, kernel=rbf, score=0.551, total=   0.0s
# [CV] C=0.1, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=0.1, gamma=0.01, kernel=rbf, score=0.562, total=   0.0s
# [CV] C=0.1, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=0.1, gamma=0.01, kernel=rbf, score=0.542, total=   0.0s
# [CV] C=0.1, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=0.1, gamma=0.01, kernel=rbf, score=0.542, total=   0.0s
# [CV] C=0.1, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=0.1, gamma=0.001, kernel=rbf, score=0.551, total=   0.0s
# [CV] C=0.1, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=0.1, gamma=0.001, kernel=rbf, score=0.551, total=   0.0s
# [CV] C=0.1, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=0.1, gamma=0.001, kernel=rbf, score=0.562, total=   0.0s
# [CV] C=0.1, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=0.1, gamma=0.001, kernel=rbf, score=0.562, total=   0.0s
# [CV] C=0.1, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=0.1, gamma=0.001, kernel=rbf, score=0.542, total=   0.0s
# [CV] C=0.1, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=0.1, gamma=0.0001, kernel=rbf, score=0.571, total=   0.0s
# [CV] C=0.1, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=0.1, gamma=0.0001, kernel=rbf, score=0.551, total=   0.0s
# [CV] C=0.1, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=0.1, gamma=0.0001, kernel=rbf, score=0.625, total=   0.0s
# [CV] C=0.1, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=0.1, gamma=0.0001, kernel=rbf, score=0.625, total=   0.0s
# [CV] C=0.1, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=0.1, gamma=0.0001, kernel=rbf, score=0.562, total=   0.0s
# [CV] C=1, gamma=1, kernel=rbf ........................................
# [CV] ............ C=1, gamma=1, kernel=rbf, score=0.551, total=   0.0s
# [CV] C=1, gamma=1, kernel=rbf ........................................
# [CV] ............ C=1, gamma=1, kernel=rbf, score=0.551, total=   0.0s
# [CV] C=1, gamma=1, kernel=rbf ........................................
# [CV] ............ C=1, gamma=1, kernel=rbf, score=0.562, total=   0.0s
# [CV] C=1, gamma=1, kernel=rbf ........................................
# [CV] ............ C=1, gamma=1, kernel=rbf, score=0.542, total=   0.0s
# [CV] C=1, gamma=1, kernel=rbf ........................................
# [CV] ............ C=1, gamma=1, kernel=rbf, score=0.542, total=   0.0s
# [CV] C=1, gamma=0.1, kernel=rbf ......................................
# [CV] .......... C=1, gamma=0.1, kernel=rbf, score=0.551, total=   0.0s
# [CV] C=1, gamma=0.1, kernel=rbf ......................................
# [CV] .......... C=1, gamma=0.1, kernel=rbf, score=0.551, total=   0.0s
# [CV] C=1, gamma=0.1, kernel=rbf ......................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [CV] .......... C=1, gamma=0.1, kernel=rbf, score=0.562, total=   0.0s
# [CV] C=1, gamma=0.1, kernel=rbf ......................................
# [CV] .......... C=1, gamma=0.1, kernel=rbf, score=0.542, total=   0.0s
# [CV] C=1, gamma=0.1, kernel=rbf ......................................
# [CV] .......... C=1, gamma=0.1, kernel=rbf, score=0.542, total=   0.0s
# [CV] C=1, gamma=0.01, kernel=rbf .....................................
# [CV] ......... C=1, gamma=0.01, kernel=rbf, score=0.551, total=   0.0s
# [CV] C=1, gamma=0.01, kernel=rbf .....................................
# [CV] ......... C=1, gamma=0.01, kernel=rbf, score=0.551, total=   0.0s
# [CV] C=1, gamma=0.01, kernel=rbf .....................................
# [CV] ......... C=1, gamma=0.01, kernel=rbf, score=0.542, total=   0.0s
# [CV] C=1, gamma=0.01, kernel=rbf .....................................
# [CV] ......... C=1, gamma=0.01, kernel=rbf, score=0.542, total=   0.0s
# [CV] C=1, gamma=0.01, kernel=rbf .....................................
# [CV] ......... C=1, gamma=0.01, kernel=rbf, score=0.604, total=   0.0s
# [CV] C=1, gamma=0.001, kernel=rbf ....................................
# [CV] ........ C=1, gamma=0.001, kernel=rbf, score=0.612, total=   0.0s
# [CV] C=1, gamma=0.001, kernel=rbf ....................................
# [CV] ........ C=1, gamma=0.001, kernel=rbf, score=0.735, total=   0.0s
# [CV] C=1, gamma=0.001, kernel=rbf ....................................
# [CV] ........ C=1, gamma=0.001, kernel=rbf, score=0.604, total=   0.0s
# [CV] C=1, gamma=0.001, kernel=rbf ....................................
# [CV] ........ C=1, gamma=0.001, kernel=rbf, score=0.521, total=   0.0s
# [CV] C=1, gamma=0.001, kernel=rbf ....................................
# [CV] ........ C=1, gamma=0.001, kernel=rbf, score=0.708, total=   0.0s
# [CV] C=1, gamma=0.0001, kernel=rbf ...................................
# [CV] ....... C=1, gamma=0.0001, kernel=rbf, score=0.694, total=   0.0s
# [CV] C=1, gamma=0.0001, kernel=rbf ...................................
# [CV] ....... C=1, gamma=0.0001, kernel=rbf, score=0.694, total=   0.0s
# [CV] C=1, gamma=0.0001, kernel=rbf ...................................
# [CV] ....... C=1, gamma=0.0001, kernel=rbf, score=0.542, total=   0.0s
# [CV] C=1, gamma=0.0001, kernel=rbf ...................................
# [CV] ....... C=1, gamma=0.0001, kernel=rbf, score=0.500, total=   0.0s
# [CV] C=1, gamma=0.0001, kernel=rbf ...................................
# [CV] ....... C=1, gamma=0.0001, kernel=rbf, score=0.729, total=   0.0s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........... C=10, gamma=1, kernel=rbf, score=0.551, total=   0.0s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........... C=10, gamma=1, kernel=rbf, score=0.551, total=   0.0s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........... C=10, gamma=1, kernel=rbf, score=0.562, total=   0.0s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........... C=10, gamma=1, kernel=rbf, score=0.542, total=   0.0s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........... C=10, gamma=1, kernel=rbf, score=0.542, total=   0.0s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ......... C=10, gamma=0.1, kernel=rbf, score=0.551, total=   0.0s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ......... C=10, gamma=0.1, kernel=rbf, score=0.551, total=   0.0s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ......... C=10, gamma=0.1, kernel=rbf, score=0.562, total=   0.0s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ......... C=10, gamma=0.1, kernel=rbf, score=0.562, total=   0.0s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ......... C=10, gamma=0.1, kernel=rbf, score=0.542, total=   0.0s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ........ C=10, gamma=0.01, kernel=rbf, score=0.531, total=   0.0s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ........ C=10, gamma=0.01, kernel=rbf, score=0.551, total=   0.0s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ........ C=10, gamma=0.01, kernel=rbf, score=0.542, total=   0.0s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ........ C=10, gamma=0.01, kernel=rbf, score=0.604, total=   0.0s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ........ C=10, gamma=0.01, kernel=rbf, score=0.583, total=   0.0s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] ....... C=10, gamma=0.001, kernel=rbf, score=0.612, total=   0.0s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] ....... C=10, gamma=0.001, kernel=rbf, score=0.592, total=   0.0s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] ....... C=10, gamma=0.001, kernel=rbf, score=0.542, total=   0.0s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] ....... C=10, gamma=0.001, kernel=rbf, score=0.542, total=   0.0s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] ....... C=10, gamma=0.001, kernel=rbf, score=0.708, total=   0.0s
# [CV] C=10, gamma=0.0001, kernel=rbf ..................................
# [CV] ...... C=10, gamma=0.0001, kernel=rbf, score=0.694, total=   0.0s
# [CV] C=10, gamma=0.0001, kernel=rbf ..................................
# [CV] ...... C=10, gamma=0.0001, kernel=rbf, score=0.694, total=   0.0s
# [CV] C=10, gamma=0.0001, kernel=rbf ..................................
# [CV] ...... C=10, gamma=0.0001, kernel=rbf, score=0.625, total=   0.0s
# [CV] C=10, gamma=0.0001, kernel=rbf ..................................
# [CV] ...... C=10, gamma=0.0001, kernel=rbf, score=0.583, total=   0.0s
# [CV] C=10, gamma=0.0001, kernel=rbf ..................................
# [CV] ...... C=10, gamma=0.0001, kernel=rbf, score=0.708, total=   0.0s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] .......... C=100, gamma=1, kernel=rbf, score=0.551, total=   0.0s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] .......... C=100, gamma=1, kernel=rbf, score=0.551, total=   0.0s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] .......... C=100, gamma=1, kernel=rbf, score=0.562, total=   0.0s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] .......... C=100, gamma=1, kernel=rbf, score=0.542, total=   0.0s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] .......... C=100, gamma=1, kernel=rbf, score=0.542, total=   0.0s
# [CV] C=100, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=100, gamma=0.1, kernel=rbf, score=0.551, total=   0.0s
# [CV] C=100, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=100, gamma=0.1, kernel=rbf, score=0.551, total=   0.0s
# [CV] C=100, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=100, gamma=0.1, kernel=rbf, score=0.562, total=   0.0s
# [CV] C=100, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=100, gamma=0.1, kernel=rbf, score=0.562, total=   0.0s
# [CV] C=100, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=100, gamma=0.1, kernel=rbf, score=0.542, total=   0.0s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=100, gamma=0.01, kernel=rbf, score=0.531, total=   0.0s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=100, gamma=0.01, kernel=rbf, score=0.551, total=   0.0s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=100, gamma=0.01, kernel=rbf, score=0.542, total=   0.0s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=100, gamma=0.01, kernel=rbf, score=0.604, total=   0.0s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=100, gamma=0.01, kernel=rbf, score=0.583, total=   0.0s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=100, gamma=0.001, kernel=rbf, score=0.612, total=   0.0s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=100, gamma=0.001, kernel=rbf, score=0.592, total=   0.0s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=100, gamma=0.001, kernel=rbf, score=0.500, total=   0.0s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=100, gamma=0.001, kernel=rbf, score=0.604, total=   0.0s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=100, gamma=0.001, kernel=rbf, score=0.729, total=   0.0s
# [CV] C=100, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=100, gamma=0.0001, kernel=rbf, score=0.816, total=   0.0s
# [CV] C=100, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=100, gamma=0.0001, kernel=rbf, score=0.837, total=   0.0s
# [CV] C=100, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=100, gamma=0.0001, kernel=rbf, score=0.688, total=   0.0s
# [CV] C=100, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=100, gamma=0.0001, kernel=rbf, score=0.792, total=   0.0s
# [CV] C=100, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=100, gamma=0.0001, kernel=rbf, score=0.792, total=   0.0s
# [CV] C=1000, gamma=1, kernel=rbf .....................................
# [CV] ......... C=1000, gamma=1, kernel=rbf, score=0.551, total=   0.0s
# [CV] C=1000, gamma=1, kernel=rbf .....................................
# [CV] ......... C=1000, gamma=1, kernel=rbf, score=0.551, total=   0.0s
# [CV] C=1000, gamma=1, kernel=rbf .....................................
# [CV] ......... C=1000, gamma=1, kernel=rbf, score=0.562, total=   0.0s
# [CV] C=1000, gamma=1, kernel=rbf .....................................
# [CV] ......... C=1000, gamma=1, kernel=rbf, score=0.542, total=   0.0s
# [CV] C=1000, gamma=1, kernel=rbf .....................................
# [CV] ......... C=1000, gamma=1, kernel=rbf, score=0.542, total=   0.0s
# [CV] C=1000, gamma=0.1, kernel=rbf ...................................
# [CV] ....... C=1000, gamma=0.1, kernel=rbf, score=0.551, total=   0.0s
# [CV] C=1000, gamma=0.1, kernel=rbf ...................................
# [CV] ....... C=1000, gamma=0.1, kernel=rbf, score=0.551, total=   0.0s
# [CV] C=1000, gamma=0.1, kernel=rbf ...................................
# [CV] ....... C=1000, gamma=0.1, kernel=rbf, score=0.562, total=   0.0s
# [CV] C=1000, gamma=0.1, kernel=rbf ...................................
# [CV] ....... C=1000, gamma=0.1, kernel=rbf, score=0.562, total=   0.0s
# [CV] C=1000, gamma=0.1, kernel=rbf ...................................
# [CV] ....... C=1000, gamma=0.1, kernel=rbf, score=0.542, total=   0.0s
# [CV] C=1000, gamma=0.01, kernel=rbf ..................................
# [CV] ...... C=1000, gamma=0.01, kernel=rbf, score=0.531, total=   0.0s
# [CV] C=1000, gamma=0.01, kernel=rbf ..................................
# [CV] ...... C=1000, gamma=0.01, kernel=rbf, score=0.551, total=   0.0s
# [CV] C=1000, gamma=0.01, kernel=rbf ..................................
# [CV] ...... C=1000, gamma=0.01, kernel=rbf, score=0.542, total=   0.0s
# [CV] C=1000, gamma=0.01, kernel=rbf ..................................
# [CV] ...... C=1000, gamma=0.01, kernel=rbf, score=0.604, total=   0.0s
# [CV] C=1000, gamma=0.01, kernel=rbf ..................................
# [CV] ...... C=1000, gamma=0.01, kernel=rbf, score=0.583, total=   0.0s
# [CV] C=1000, gamma=0.001, kernel=rbf .................................
# [CV] ..... C=1000, gamma=0.001, kernel=rbf, score=0.633, total=   0.0s
# [CV] C=1000, gamma=0.001, kernel=rbf .................................
# [CV] ..... C=1000, gamma=0.001, kernel=rbf, score=0.571, total=   0.0s
# [CV] C=1000, gamma=0.001, kernel=rbf .................................
# [CV] ..... C=1000, gamma=0.001, kernel=rbf, score=0.500, total=   0.0s
# [CV] C=1000, gamma=0.001, kernel=rbf .................................
# [CV] ..... C=1000, gamma=0.001, kernel=rbf, score=0.604, total=   0.0s
# [CV] C=1000, gamma=0.001, kernel=rbf .................................
# [CV] ..... C=1000, gamma=0.001, kernel=rbf, score=0.688, total=   0.0s
# [CV] C=1000, gamma=0.0001, kernel=rbf ................................
# [CV] .... C=1000, gamma=0.0001, kernel=rbf, score=0.653, total=   0.0s
# [CV] C=1000, gamma=0.0001, kernel=rbf ................................
# [CV] .... C=1000, gamma=0.0001, kernel=rbf, score=0.776, total=   0.0s
# [CV] C=1000, gamma=0.0001, kernel=rbf ................................
# [CV] .... C=1000, gamma=0.0001, kernel=rbf, score=0.708, total=   0.0s
# [CV] C=1000, gamma=0.0001, kernel=rbf ................................
# [CV] .... C=1000, gamma=0.0001, kernel=rbf, score=0.729, total=   0.0s
# [CV] C=1000, gamma=0.0001, kernel=rbf ................................
# [CV] .... C=1000, gamma=0.0001, kernel=rbf, score=0.812, total=   0.0s
# [Parallel(n_jobs=1)]: Done 125 out of 125 | elapsed:    0.8s finished
# GridSearchCV(cv=None, error_score=nan,
#              estimator=SVC(C=1.0, break_ties=False, cache_size=200,
#                            class_weight=None, coef0=0.0,
#                            decision_function_shape='ovr', degree=3,
#                            gamma='scale', kernel='rbf', max_iter=-1,
#                            probability=False, random_state=42, shrinking=True,
#                            tol=0.001, verbose=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'C': [0.1, 1, 10, 100, 1000],
#                          'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#                          'kernel': ['rbf']},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %%
# print best parameter after tuning 
print(grid1.best_params_) 
  
# print how our model looks after hyper-parameter tuning 
print(grid1.best_estimator_)
# Out:
# {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# SVC(C=100, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma=0.0001, kernel='rbf',
#     max_iter=-1, probability=False, random_state=42, shrinking=True, tol=0.001,
#     verbose=False)

# %%
#testing
y_pred = grid1.predict(X_test)

score = accuracy_score(y_test, y_pred)
print("Accuracy of SVM classifier is",score*100,"%")
# Out:
# Accuracy of SVM classifier is 83.60655737704919 %

# %% [markdown]
# # XGBOOST

# %%
from xgboost import XGBClassifier

# %%
param_grid = {'n_estimator': [10, 100, 1000, 2000, 3000],  
              'gamma': [50, 25, 12, 10, 5, 1], 
              'max_depth': [4,5,6,7,8,9,10]}

# %%
 
xgb_clf = XGBClassifier(scale_pos_weight=1,
                          learning_rate=0.001,  
                          colsample_bytree = 0.4,
                          subsample = 0.2,
                          objective='binary:logistic', 
                          n_estimators=1500, 
                          reg_alpha = 0.3,
                          max_depth=5, 
                          gamma= 5,
                          random_state = random_state,
                       )
xgb_clf.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster=None, colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.4, gamma=5, gpu_id=-1,
#               importance_type='gain', interaction_constraints=None,
#               learning_rate=0.001, max_delta_step=0, max_depth=5,
#               min_child_weight=1, missing=nan, monotone_constraints=None,
#               n_estimators=1500, n_jobs=0, num_parallel_tree=1,
#               objective='binary:logistic', random_state=42, reg_alpha=0.3,
#               reg_lambda=1, scale_pos_weight=1, subsample=0.2, tree_method=None,
#               validate_parameters=False, verbosity=None)

# %%
#testing
y_pred = xgb_clf.predict(X_test)

score = accuracy_score(y_test, y_pred)
print("Accuracy of XGBOOST classifier is",score*100,"%")
# Out:
# Accuracy of XGBOOST classifier is 86.88524590163934 %

# %%
param_grid = {'n_estimator': [10, 100, 1000, 2000, 3000],  
              'gamma': [50, 25, 12, 10, 5, 1],
              'learning_rate':[0.1,0.01,0.001,0.0001]}
              #'max_depth': [4,5,6,7,8,9,10]} 

grid2 = GridSearchCV(XGBClassifier( max_depth = 4,
                                    random_state = random_state),
                    param_grid,
                    refit = True,
                    verbose = 3) 
  
# fitting the model for grid
grid2.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 120 candidates, totalling 600 fits
# [CV] gamma=50, learning_rate=0.1, n_estimator=10 .....................
# [CV]  gamma=50, learning_rate=0.1, n_estimator=10, score=0.551, total=   0.0s
# [CV] gamma=50, learning_rate=0.1, n_estimator=10 .....................
# [CV]  gamma=50, learning_rate=0.1, n_estimator=10, score=0.551, total=   0.0s
# [CV] gamma=50, learning_rate=0.1, n_estimator=10 .....................
# [CV]  gamma=50, learning_rate=0.1, n_estimator=10, score=0.562, total=   0.0s
# [CV] gamma=50, learning_rate=0.1, n_estimator=10 .....................
# [CV]  gamma=50, learning_rate=0.1, n_estimator=10, score=0.542, total=   0.0s
# [CV] gamma=50, learning_rate=0.1, n_estimator=10 .....................
# [CV]  gamma=50, learning_rate=0.1, n_estimator=10, score=0.542, total=   0.0s
# [CV] gamma=50, learning_rate=0.1, n_estimator=100 ....................
# [CV]  gamma=50, learning_rate=0.1, n_estimator=100, score=0.551, total=   0.0s
# [CV] gamma=50, learning_rate=0.1, n_estimator=100 ....................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [CV]  gamma=50, learning_rate=0.1, n_estimator=100, score=0.551, total=   0.0s
# [CV] gamma=50, learning_rate=0.1, n_estimator=100 ....................
# [CV]  gamma=50, learning_rate=0.1, n_estimator=100, score=0.562, total=   0.0s
# [CV] gamma=50, learning_rate=0.1, n_estimator=100 ....................
# [CV]  gamma=50, learning_rate=0.1, n_estimator=100, score=0.542, total=   0.0s
# [CV] gamma=50, learning_rate=0.1, n_estimator=100 ....................
# [CV]  gamma=50, learning_rate=0.1, n_estimator=100, score=0.542, total=   0.0s
# [CV] gamma=50, learning_rate=0.1, n_estimator=1000 ...................
# [CV]  gamma=50, learning_rate=0.1, n_estimator=1000, score=0.551, total=   0.0s
# [CV] gamma=50, learning_rate=0.1, n_estimator=1000 ...................
# [CV]  gamma=50, learning_rate=0.1, n_estimator=1000, score=0.551, total=   0.0s
# [CV] gamma=50, learning_rate=0.1, n_estimator=1000 ...................
# [CV]  gamma=50, learning_rate=0.1, n_estimator=1000, score=0.562, total=   0.0s
# [CV] gamma=50, learning_rate=0.1, n_estimator=1000 ...................
# [CV]  gamma=50, learning_rate=0.1, n_estimator=1000, score=0.542, total=   0.0s
# [CV] gamma=50, learning_rate=0.1, n_estimator=1000 ...................
# [CV]  gamma=50, learning_rate=0.1, n_estimator=1000, score=0.542, total=   0.0s
# [CV] gamma=50, learning_rate=0.1, n_estimator=2000 ...................
# [CV]  gamma=50, learning_rate=0.1, n_estimator=2000, score=0.551, total=   0.0s
# [CV] gamma=50, learning_rate=0.1, n_estimator=2000 ...................
# [CV]  gamma=50, learning_rate=0.1, n_estimator=2000, score=0.551, total=   0.0s
# [CV] gamma=50, learning_rate=0.1, n_estimator=2000 ...................
# [CV]  gamma=50, learning_rate=0.1, n_estimator=2000, score=0.562, total=   0.0s
# [CV] gamma=50, learning_rate=0.1, n_estimator=2000 ...................
# [CV]  gamma=50, learning_rate=0.1, n_estimator=2000, score=0.542, total=   0.0s
# [CV] gamma=50, learning_rate=0.1, n_estimator=2000 ...................
# [CV]  gamma=50, learning_rate=0.1, n_estimator=2000, score=0.542, total=   0.0s
# [CV] gamma=50, learning_rate=0.1, n_estimator=3000 ...................
# [CV]  gamma=50, learning_rate=0.1, n_estimator=3000, score=0.551, total=   0.0s
# [CV] gamma=50, learning_rate=0.1, n_estimator=3000 ...................
# [CV]  gamma=50, learning_rate=0.1, n_estimator=3000, score=0.551, total=   0.0s
# [CV] gamma=50, learning_rate=0.1, n_estimator=3000 ...................
# [CV]  gamma=50, learning_rate=0.1, n_estimator=3000, score=0.562, total=   0.0s
# [CV] gamma=50, learning_rate=0.1, n_estimator=3000 ...................
# [CV]  gamma=50, learning_rate=0.1, n_estimator=3000, score=0.542, total=   0.0s
# [CV] gamma=50, learning_rate=0.1, n_estimator=3000 ...................
# [CV]  gamma=50, learning_rate=0.1, n_estimator=3000, score=0.542, total=   0.0s
# [CV] gamma=50, learning_rate=0.01, n_estimator=10 ....................
# [CV]  gamma=50, learning_rate=0.01, n_estimator=10, score=0.551, total=   0.0s
# [CV] gamma=50, learning_rate=0.01, n_estimator=10 ....................
# [CV]  gamma=50, learning_rate=0.01, n_estimator=10, score=0.551, total=   0.0s
# [CV] gamma=50, learning_rate=0.01, n_estimator=10 ....................
# [CV]  gamma=50, learning_rate=0.01, n_estimator=10, score=0.562, total=   0.0s
# [CV] gamma=50, learning_rate=0.01, n_estimator=10 ....................
# [CV]  gamma=50, learning_rate=0.01, n_estimator=10, score=0.542, total=   0.0s
# [CV] gamma=50, learning_rate=0.01, n_estimator=10 ....................
# [CV]  gamma=50, learning_rate=0.01, n_estimator=10, score=0.542, total=   0.0s
# [CV] gamma=50, learning_rate=0.01, n_estimator=100 ...................
# [CV]  gamma=50, learning_rate=0.01, n_estimator=100, score=0.551, total=   0.0s
# [CV] gamma=50, learning_rate=0.01, n_estimator=100 ...................
# [CV]  gamma=50, learning_rate=0.01, n_estimator=100, score=0.551, total=   0.0s
# [CV] gamma=50, learning_rate=0.01, n_estimator=100 ...................
# [CV]  gamma=50, learning_rate=0.01, n_estimator=100, score=0.562, total=   0.0s
# [CV] gamma=50, learning_rate=0.01, n_estimator=100 ...................
# [CV]  gamma=50, learning_rate=0.01, n_estimator=100, score=0.542, total=   0.0s
# [CV] gamma=50, learning_rate=0.01, n_estimator=100 ...................
# [CV]  gamma=50, learning_rate=0.01, n_estimator=100, score=0.542, total=   0.0s
# [CV] gamma=50, learning_rate=0.01, n_estimator=1000 ..................
# [CV]  gamma=50, learning_rate=0.01, n_estimator=1000, score=0.551, total=   0.0s
# [CV] gamma=50, learning_rate=0.01, n_estimator=1000 ..................
# [CV]  gamma=50, learning_rate=0.01, n_estimator=1000, score=0.551, total=   0.0s
# [CV] gamma=50, learning_rate=0.01, n_estimator=1000 ..................
# [CV]  gamma=50, learning_rate=0.01, n_estimator=1000, score=0.562, total=   0.0s
# [CV] gamma=50, learning_rate=0.01, n_estimator=1000 ..................
# [CV]  gamma=50, learning_rate=0.01, n_estimator=1000, score=0.542, total=   0.0s
# [CV] gamma=50, learning_rate=0.01, n_estimator=1000 ..................
# [CV]  gamma=50, learning_rate=0.01, n_estimator=1000, score=0.542, total=   0.0s
# [CV] gamma=50, learning_rate=0.01, n_estimator=2000 ..................
# [CV]  gamma=50, learning_rate=0.01, n_estimator=2000, score=0.551, total=   0.0s
# [CV] gamma=50, learning_rate=0.01, n_estimator=2000 ..................
# [CV]  gamma=50, learning_rate=0.01, n_estimator=2000, score=0.551, total=   0.0s
# [CV] gamma=50, learning_rate=0.01, n_estimator=2000 ..................
# [CV]  gamma=50, learning_rate=0.01, n_estimator=2000, score=0.562, total=   0.0s
# [CV] gamma=50, learning_rate=0.01, n_estimator=2000 ..................
# [CV]  gamma=50, learning_rate=0.01, n_estimator=2000, score=0.542, total=   0.0s
# [CV] gamma=50, learning_rate=0.01, n_estimator=2000 ..................
# [CV]  gamma=50, learning_rate=0.01, n_estimator=2000, score=0.542, total=   0.0s
# [CV] gamma=50, learning_rate=0.01, n_estimator=3000 ..................
# [CV]  gamma=50, learning_rate=0.01, n_estimator=3000, score=0.551, total=   0.0s
# [CV] gamma=50, learning_rate=0.01, n_estimator=3000 ..................
# [CV]  gamma=50, learning_rate=0.01, n_estimator=3000, score=0.551, total=   0.0s
# [CV] gamma=50, learning_rate=0.01, n_estimator=3000 ..................
# [CV]  gamma=50, learning_rate=0.01, n_estimator=3000, score=0.562, total=   0.0s
# [CV] gamma=50, learning_rate=0.01, n_estimator=3000 ..................
# [CV]  gamma=50, learning_rate=0.01, n_estimator=3000, score=0.542, total=   0.0s
# [CV] gamma=50, learning_rate=0.01, n_estimator=3000 ..................
# [CV]  gamma=50, learning_rate=0.01, n_estimator=3000, score=0.542, total=   0.0s
# [CV] gamma=50, learning_rate=0.001, n_estimator=10 ...................
# [CV]  gamma=50, learning_rate=0.001, n_estimator=10, score=0.551, total=   0.0s
# [CV] gamma=50, learning_rate=0.001, n_estimator=10 ...................
# [CV]  gamma=50, learning_rate=0.001, n_estimator=10, score=0.551, total=   0.0s
# [CV] gamma=50, learning_rate=0.001, n_estimator=10 ...................
# [CV]  gamma=50, learning_rate=0.001, n_estimator=10, score=0.562, total=   0.0s
# [CV] gamma=50, learning_rate=0.001, n_estimator=10 ...................
# [CV]  gamma=50, learning_rate=0.001, n_estimator=10, score=0.542, total=   0.0s
# [CV] gamma=50, learning_rate=0.001, n_estimator=10 ...................
# [CV]  gamma=50, learning_rate=0.001, n_estimator=10, score=0.542, total=   0.0s
# [CV] gamma=50, learning_rate=0.001, n_estimator=100 ..................
# [CV]  gamma=50, learning_rate=0.001, n_estimator=100, score=0.551, total=   0.0s
# [CV] gamma=50, learning_rate=0.001, n_estimator=100 ..................
# [CV]  gamma=50, learning_rate=0.001, n_estimator=100, score=0.551, total=   0.0s
# [CV] gamma=50, learning_rate=0.001, n_estimator=100 ..................
# [CV]  gamma=50, learning_rate=0.001, n_estimator=100, score=0.562, total=   0.0s
# [CV] gamma=50, learning_rate=0.001, n_estimator=100 ..................
# [CV]  gamma=50, learning_rate=0.001, n_estimator=100, score=0.542, total=   0.0s
# [CV] gamma=50, learning_rate=0.001, n_estimator=100 ..................
# [CV]  gamma=50, learning_rate=0.001, n_estimator=100, score=0.542, total=   0.0s
# [CV] gamma=50, learning_rate=0.001, n_estimator=1000 .................
# [CV]  gamma=50, learning_rate=0.001, n_estimator=1000, score=0.551, total=   0.0s
# [CV] gamma=50, learning_rate=0.001, n_estimator=1000 .................
# [CV]  gamma=50, learning_rate=0.001, n_estimator=1000, score=0.551, total=   0.0s
# [CV] gamma=50, learning_rate=0.001, n_estimator=1000 .................
# [CV]  gamma=50, learning_rate=0.001, n_estimator=1000, score=0.562, total=   0.0s
# [CV] gamma=50, learning_rate=0.001, n_estimator=1000 .................
# [CV]  gamma=50, learning_rate=0.001, n_estimator=1000, score=0.542, total=   0.0s
# [CV] gamma=50, learning_rate=0.001, n_estimator=1000 .................
# [CV]  gamma=50, learning_rate=0.001, n_estimator=1000, score=0.542, total=   0.0s
# [CV] gamma=50, learning_rate=0.001, n_estimator=2000 .................
# [CV]  gamma=50, learning_rate=0.001, n_estimator=2000, score=0.551, total=   0.0s
# [CV] gamma=50, learning_rate=0.001, n_estimator=2000 .................
# [CV]  gamma=50, learning_rate=0.001, n_estimator=2000, score=0.551, total=   0.0s
# [CV] gamma=50, learning_rate=0.001, n_estimator=2000 .................
# [CV]  gamma=50, learning_rate=0.001, n_estimator=2000, score=0.562, total=   0.0s
# [CV] gamma=50, learning_rate=0.001, n_estimator=2000 .................
# [CV]  gamma=50, learning_rate=0.001, n_estimator=2000, score=0.542, total=   0.0s
# [CV] gamma=50, learning_rate=0.001, n_estimator=2000 .................
# [CV]  gamma=50, learning_rate=0.001, n_estimator=2000, score=0.542, total=   0.0s
# [CV] gamma=50, learning_rate=0.001, n_estimator=3000 .................
# [CV]  gamma=50, learning_rate=0.001, n_estimator=3000, score=0.551, total=   0.0s
# [CV] gamma=50, learning_rate=0.001, n_estimator=3000 .................
# [CV]  gamma=50, learning_rate=0.001, n_estimator=3000, score=0.551, total=   0.0s
# [CV] gamma=50, learning_rate=0.001, n_estimator=3000 .................
# [CV]  gamma=50, learning_rate=0.001, n_estimator=3000, score=0.562, total=   0.0s
# [CV] gamma=50, learning_rate=0.001, n_estimator=3000 .................
# [CV]  gamma=50, learning_rate=0.001, n_estimator=3000, score=0.542, total=   0.0s
# [CV] gamma=50, learning_rate=0.001, n_estimator=3000 .................
# [CV]  gamma=50, learning_rate=0.001, n_estimator=3000, score=0.542, total=   0.0s
# [CV] gamma=50, learning_rate=0.0001, n_estimator=10 ..................
# [CV]  gamma=50, learning_rate=0.0001, n_estimator=10, score=0.551, total=   0.0s
# [CV] gamma=50, learning_rate=0.0001, n_estimator=10 ..................
# [CV]  gamma=50, learning_rate=0.0001, n_estimator=10, score=0.551, total=   0.0s
# [CV] gamma=50, learning_rate=0.0001, n_estimator=10 ..................
# [CV]  gamma=50, learning_rate=0.0001, n_estimator=10, score=0.562, total=   0.0s
# [CV] gamma=50, learning_rate=0.0001, n_estimator=10 ..................
# [CV]  gamma=50, learning_rate=0.0001, n_estimator=10, score=0.542, total=   0.0s
# [CV] gamma=50, learning_rate=0.0001, n_estimator=10 ..................
# [CV]  gamma=50, learning_rate=0.0001, n_estimator=10, score=0.542, total=   0.0s
# [CV] gamma=50, learning_rate=0.0001, n_estimator=100 .................
# [CV]  gamma=50, learning_rate=0.0001, n_estimator=100, score=0.551, total=   0.0s
# [CV] gamma=50, learning_rate=0.0001, n_estimator=100 .................
# [CV]  gamma=50, learning_rate=0.0001, n_estimator=100, score=0.551, total=   0.0s
# [CV] gamma=50, learning_rate=0.0001, n_estimator=100 .................
# [CV]  gamma=50, learning_rate=0.0001, n_estimator=100, score=0.562, total=   0.0s
# [CV] gamma=50, learning_rate=0.0001, n_estimator=100 .................
# [CV]  gamma=50, learning_rate=0.0001, n_estimator=100, score=0.542, total=   0.0s
# [CV] gamma=50, learning_rate=0.0001, n_estimator=100 .................
# [CV]  gamma=50, learning_rate=0.0001, n_estimator=100, score=0.542, total=   0.0s
# [CV] gamma=50, learning_rate=0.0001, n_estimator=1000 ................
# [CV]  gamma=50, learning_rate=0.0001, n_estimator=1000, score=0.551, total=   0.0s
# [CV] gamma=50, learning_rate=0.0001, n_estimator=1000 ................
# [CV]  gamma=50, learning_rate=0.0001, n_estimator=1000, score=0.551, total=   0.0s
# [CV] gamma=50, learning_rate=0.0001, n_estimator=1000 ................
# [CV]  gamma=50, learning_rate=0.0001, n_estimator=1000, score=0.562, total=   0.0s
# [CV] gamma=50, learning_rate=0.0001, n_estimator=1000 ................
# [CV]  gamma=50, learning_rate=0.0001, n_estimator=1000, score=0.542, total=   0.0s
# [CV] gamma=50, learning_rate=0.0001, n_estimator=1000 ................
# [CV]  gamma=50, learning_rate=0.0001, n_estimator=1000, score=0.542, total=   0.0s
# [CV] gamma=50, learning_rate=0.0001, n_estimator=2000 ................
# [CV]  gamma=50, learning_rate=0.0001, n_estimator=2000, score=0.551, total=   0.0s
# [CV] gamma=50, learning_rate=0.0001, n_estimator=2000 ................
# [CV]  gamma=50, learning_rate=0.0001, n_estimator=2000, score=0.551, total=   0.0s
# [CV] gamma=50, learning_rate=0.0001, n_estimator=2000 ................
# [CV]  gamma=50, learning_rate=0.0001, n_estimator=2000, score=0.562, total=   0.0s
# [CV] gamma=50, learning_rate=0.0001, n_estimator=2000 ................
# [CV]  gamma=50, learning_rate=0.0001, n_estimator=2000, score=0.542, total=   0.0s
# [CV] gamma=50, learning_rate=0.0001, n_estimator=2000 ................
# [CV]  gamma=50, learning_rate=0.0001, n_estimator=2000, score=0.542, total=   0.0s
# [CV] gamma=50, learning_rate=0.0001, n_estimator=3000 ................
# [CV]  gamma=50, learning_rate=0.0001, n_estimator=3000, score=0.551, total=   0.0s
# [CV] gamma=50, learning_rate=0.0001, n_estimator=3000 ................
# [CV]  gamma=50, learning_rate=0.0001, n_estimator=3000, score=0.551, total=   0.0s
# [CV] gamma=50, learning_rate=0.0001, n_estimator=3000 ................
# [CV]  gamma=50, learning_rate=0.0001, n_estimator=3000, score=0.562, total=   0.0s
# [CV] gamma=50, learning_rate=0.0001, n_estimator=3000 ................
# [CV]  gamma=50, learning_rate=0.0001, n_estimator=3000, score=0.542, total=   0.0s
# [CV] gamma=50, learning_rate=0.0001, n_estimator=3000 ................
# [CV]  gamma=50, learning_rate=0.0001, n_estimator=3000, score=0.542, total=   0.0s
# [CV] gamma=25, learning_rate=0.1, n_estimator=10 .....................
# [CV]  gamma=25, learning_rate=0.1, n_estimator=10, score=0.755, total=   0.0s
# [CV] gamma=25, learning_rate=0.1, n_estimator=10 .....................
# [CV]  gamma=25, learning_rate=0.1, n_estimator=10, score=0.837, total=   0.0s
# [CV] gamma=25, learning_rate=0.1, n_estimator=10 .....................
# [CV]  gamma=25, learning_rate=0.1, n_estimator=10, score=0.792, total=   0.0s
# [CV] gamma=25, learning_rate=0.1, n_estimator=10 .....................
# [CV]  gamma=25, learning_rate=0.1, n_estimator=10, score=0.812, total=   0.0s
# [CV] gamma=25, learning_rate=0.1, n_estimator=10 .....................
# [CV]  gamma=25, learning_rate=0.1, n_estimator=10, score=0.750, total=   0.0s
# [CV] gamma=25, learning_rate=0.1, n_estimator=100 ....................
# [CV]  gamma=25, learning_rate=0.1, n_estimator=100, score=0.755, total=   0.0s
# [CV] gamma=25, learning_rate=0.1, n_estimator=100 ....................
# [CV]  gamma=25, learning_rate=0.1, n_estimator=100, score=0.837, total=   0.0s
# [CV] gamma=25, learning_rate=0.1, n_estimator=100 ....................
# [CV]  gamma=25, learning_rate=0.1, n_estimator=100, score=0.792, total=   0.0s
# [CV] gamma=25, learning_rate=0.1, n_estimator=100 ....................
# [CV]  gamma=25, learning_rate=0.1, n_estimator=100, score=0.812, total=   0.0s
# [CV] gamma=25, learning_rate=0.1, n_estimator=100 ....................
# [CV]  gamma=25, learning_rate=0.1, n_estimator=100, score=0.750, total=   0.0s
# [CV] gamma=25, learning_rate=0.1, n_estimator=1000 ...................
# [CV]  gamma=25, learning_rate=0.1, n_estimator=1000, score=0.755, total=   0.0s
# [CV] gamma=25, learning_rate=0.1, n_estimator=1000 ...................
# [CV]  gamma=25, learning_rate=0.1, n_estimator=1000, score=0.837, total=   0.0s
# [CV] gamma=25, learning_rate=0.1, n_estimator=1000 ...................
# [CV]  gamma=25, learning_rate=0.1, n_estimator=1000, score=0.792, total=   0.0s
# [CV] gamma=25, learning_rate=0.1, n_estimator=1000 ...................
# [CV]  gamma=25, learning_rate=0.1, n_estimator=1000, score=0.812, total=   0.0s
# [CV] gamma=25, learning_rate=0.1, n_estimator=1000 ...................
# [CV]  gamma=25, learning_rate=0.1, n_estimator=1000, score=0.750, total=   0.0s
# [CV] gamma=25, learning_rate=0.1, n_estimator=2000 ...................
# [CV]  gamma=25, learning_rate=0.1, n_estimator=2000, score=0.755, total=   0.0s
# [CV] gamma=25, learning_rate=0.1, n_estimator=2000 ...................
# [CV]  gamma=25, learning_rate=0.1, n_estimator=2000, score=0.837, total=   0.0s
# [CV] gamma=25, learning_rate=0.1, n_estimator=2000 ...................
# [CV]  gamma=25, learning_rate=0.1, n_estimator=2000, score=0.792, total=   0.0s
# [CV] gamma=25, learning_rate=0.1, n_estimator=2000 ...................
# [CV]  gamma=25, learning_rate=0.1, n_estimator=2000, score=0.812, total=   0.0s
# [CV] gamma=25, learning_rate=0.1, n_estimator=2000 ...................
# [CV]  gamma=25, learning_rate=0.1, n_estimator=2000, score=0.750, total=   0.0s
# [CV] gamma=25, learning_rate=0.1, n_estimator=3000 ...................
# [CV]  gamma=25, learning_rate=0.1, n_estimator=3000, score=0.755, total=   0.0s
# [CV] gamma=25, learning_rate=0.1, n_estimator=3000 ...................
# [CV]  gamma=25, learning_rate=0.1, n_estimator=3000, score=0.837, total=   0.0s
# [CV] gamma=25, learning_rate=0.1, n_estimator=3000 ...................
# [CV]  gamma=25, learning_rate=0.1, n_estimator=3000, score=0.792, total=   0.0s
# [CV] gamma=25, learning_rate=0.1, n_estimator=3000 ...................
# [CV]  gamma=25, learning_rate=0.1, n_estimator=3000, score=0.812, total=   0.0s
# [CV] gamma=25, learning_rate=0.1, n_estimator=3000 ...................
# [CV]  gamma=25, learning_rate=0.1, n_estimator=3000, score=0.750, total=   0.0s
# [CV] gamma=25, learning_rate=0.01, n_estimator=10 ....................
# [CV]  gamma=25, learning_rate=0.01, n_estimator=10, score=0.755, total=   0.0s
# [CV] gamma=25, learning_rate=0.01, n_estimator=10 ....................
# [CV]  gamma=25, learning_rate=0.01, n_estimator=10, score=0.837, total=   0.0s
# [CV] gamma=25, learning_rate=0.01, n_estimator=10 ....................
# [CV]  gamma=25, learning_rate=0.01, n_estimator=10, score=0.771, total=   0.0s
# [CV] gamma=25, learning_rate=0.01, n_estimator=10 ....................
# [CV]  gamma=25, learning_rate=0.01, n_estimator=10, score=0.833, total=   0.0s
# [CV] gamma=25, learning_rate=0.01, n_estimator=10 ....................
# [CV]  gamma=25, learning_rate=0.01, n_estimator=10, score=0.792, total=   0.0s
# [CV] gamma=25, learning_rate=0.01, n_estimator=100 ...................
# [CV]  gamma=25, learning_rate=0.01, n_estimator=100, score=0.755, total=   0.0s
# [CV] gamma=25, learning_rate=0.01, n_estimator=100 ...................
# [CV]  gamma=25, learning_rate=0.01, n_estimator=100, score=0.837, total=   0.0s
# [CV] gamma=25, learning_rate=0.01, n_estimator=100 ...................
# [CV]  gamma=25, learning_rate=0.01, n_estimator=100, score=0.771, total=   0.0s
# [CV] gamma=25, learning_rate=0.01, n_estimator=100 ...................
# [CV]  gamma=25, learning_rate=0.01, n_estimator=100, score=0.833, total=   0.0s
# [CV] gamma=25, learning_rate=0.01, n_estimator=100 ...................
# [CV]  gamma=25, learning_rate=0.01, n_estimator=100, score=0.792, total=   0.0s
# [CV] gamma=25, learning_rate=0.01, n_estimator=1000 ..................
# [CV]  gamma=25, learning_rate=0.01, n_estimator=1000, score=0.755, total=   0.1s
# [CV] gamma=25, learning_rate=0.01, n_estimator=1000 ..................
# [CV]  gamma=25, learning_rate=0.01, n_estimator=1000, score=0.837, total=   0.0s
# [CV] gamma=25, learning_rate=0.01, n_estimator=1000 ..................
# [CV]  gamma=25, learning_rate=0.01, n_estimator=1000, score=0.771, total=   0.0s
# [CV] gamma=25, learning_rate=0.01, n_estimator=1000 ..................
# [CV]  gamma=25, learning_rate=0.01, n_estimator=1000, score=0.833, total=   0.0s
# [CV] gamma=25, learning_rate=0.01, n_estimator=1000 ..................
# [CV]  gamma=25, learning_rate=0.01, n_estimator=1000, score=0.792, total=   0.0s
# [CV] gamma=25, learning_rate=0.01, n_estimator=2000 ..................
# [CV]  gamma=25, learning_rate=0.01, n_estimator=2000, score=0.755, total=   0.0s
# [CV] gamma=25, learning_rate=0.01, n_estimator=2000 ..................
# [CV]  gamma=25, learning_rate=0.01, n_estimator=2000, score=0.837, total=   0.0s
# [CV] gamma=25, learning_rate=0.01, n_estimator=2000 ..................
# [CV]  gamma=25, learning_rate=0.01, n_estimator=2000, score=0.771, total=   0.0s
# [CV] gamma=25, learning_rate=0.01, n_estimator=2000 ..................
# [CV]  gamma=25, learning_rate=0.01, n_estimator=2000, score=0.833, total=   0.0s
# [CV] gamma=25, learning_rate=0.01, n_estimator=2000 ..................
# [CV]  gamma=25, learning_rate=0.01, n_estimator=2000, score=0.792, total=   0.0s
# [CV] gamma=25, learning_rate=0.01, n_estimator=3000 ..................
# [CV]  gamma=25, learning_rate=0.01, n_estimator=3000, score=0.755, total=   0.0s
# [CV] gamma=25, learning_rate=0.01, n_estimator=3000 ..................
# [CV]  gamma=25, learning_rate=0.01, n_estimator=3000, score=0.837, total=   0.0s
# [CV] gamma=25, learning_rate=0.01, n_estimator=3000 ..................
# [CV]  gamma=25, learning_rate=0.01, n_estimator=3000, score=0.771, total=   0.0s
# [CV] gamma=25, learning_rate=0.01, n_estimator=3000 ..................
# [CV]  gamma=25, learning_rate=0.01, n_estimator=3000, score=0.833, total=   0.0s
# [CV] gamma=25, learning_rate=0.01, n_estimator=3000 ..................
# [CV]  gamma=25, learning_rate=0.01, n_estimator=3000, score=0.792, total=   0.0s
# [CV] gamma=25, learning_rate=0.001, n_estimator=10 ...................
# [CV]  gamma=25, learning_rate=0.001, n_estimator=10, score=0.755, total=   0.0s
# [CV] gamma=25, learning_rate=0.001, n_estimator=10 ...................
# [CV]  gamma=25, learning_rate=0.001, n_estimator=10, score=0.714, total=   0.0s
# [CV] gamma=25, learning_rate=0.001, n_estimator=10 ...................
# [CV]  gamma=25, learning_rate=0.001, n_estimator=10, score=0.688, total=   0.0s
# [CV] gamma=25, learning_rate=0.001, n_estimator=10 ...................
# [CV]  gamma=25, learning_rate=0.001, n_estimator=10, score=0.771, total=   0.0s
# [CV] gamma=25, learning_rate=0.001, n_estimator=10 ...................
# [CV]  gamma=25, learning_rate=0.001, n_estimator=10, score=0.729, total=   0.0s
# [CV] gamma=25, learning_rate=0.001, n_estimator=100 ..................
# [CV]  gamma=25, learning_rate=0.001, n_estimator=100, score=0.755, total=   0.0s
# [CV] gamma=25, learning_rate=0.001, n_estimator=100 ..................
# [CV]  gamma=25, learning_rate=0.001, n_estimator=100, score=0.714, total=   0.0s
# [CV] gamma=25, learning_rate=0.001, n_estimator=100 ..................
# [CV]  gamma=25, learning_rate=0.001, n_estimator=100, score=0.688, total=   0.0s
# [CV] gamma=25, learning_rate=0.001, n_estimator=100 ..................
# [CV]  gamma=25, learning_rate=0.001, n_estimator=100, score=0.771, total=   0.0s
# [CV] gamma=25, learning_rate=0.001, n_estimator=100 ..................
# [CV]  gamma=25, learning_rate=0.001, n_estimator=100, score=0.729, total=   0.0s
# [CV] gamma=25, learning_rate=0.001, n_estimator=1000 .................
# [CV]  gamma=25, learning_rate=0.001, n_estimator=1000, score=0.755, total=   0.0s
# [CV] gamma=25, learning_rate=0.001, n_estimator=1000 .................
# [CV]  gamma=25, learning_rate=0.001, n_estimator=1000, score=0.714, total=   0.0s
# [CV] gamma=25, learning_rate=0.001, n_estimator=1000 .................
# [CV]  gamma=25, learning_rate=0.001, n_estimator=1000, score=0.688, total=   0.0s
# [CV] gamma=25, learning_rate=0.001, n_estimator=1000 .................
# [CV]  gamma=25, learning_rate=0.001, n_estimator=1000, score=0.771, total=   0.0s
# [CV] gamma=25, learning_rate=0.001, n_estimator=1000 .................
# [CV]  gamma=25, learning_rate=0.001, n_estimator=1000, score=0.729, total=   0.0s
# [CV] gamma=25, learning_rate=0.001, n_estimator=2000 .................
# [CV]  gamma=25, learning_rate=0.001, n_estimator=2000, score=0.755, total=   0.0s
# [CV] gamma=25, learning_rate=0.001, n_estimator=2000 .................
# [CV]  gamma=25, learning_rate=0.001, n_estimator=2000, score=0.714, total=   0.0s
# [CV] gamma=25, learning_rate=0.001, n_estimator=2000 .................
# [CV]  gamma=25, learning_rate=0.001, n_estimator=2000, score=0.688, total=   0.0s
# [CV] gamma=25, learning_rate=0.001, n_estimator=2000 .................
# [CV]  gamma=25, learning_rate=0.001, n_estimator=2000, score=0.771, total=   0.0s
# [CV] gamma=25, learning_rate=0.001, n_estimator=2000 .................
# [CV]  gamma=25, learning_rate=0.001, n_estimator=2000, score=0.729, total=   0.0s
# [CV] gamma=25, learning_rate=0.001, n_estimator=3000 .................
# [CV]  gamma=25, learning_rate=0.001, n_estimator=3000, score=0.755, total=   0.0s
# [CV] gamma=25, learning_rate=0.001, n_estimator=3000 .................
# [CV]  gamma=25, learning_rate=0.001, n_estimator=3000, score=0.714, total=   0.0s
# [CV] gamma=25, learning_rate=0.001, n_estimator=3000 .................
# [CV]  gamma=25, learning_rate=0.001, n_estimator=3000, score=0.688, total=   0.0s
# [CV] gamma=25, learning_rate=0.001, n_estimator=3000 .................
# [CV]  gamma=25, learning_rate=0.001, n_estimator=3000, score=0.771, total=   0.0s
# [CV] gamma=25, learning_rate=0.001, n_estimator=3000 .................
# [CV]  gamma=25, learning_rate=0.001, n_estimator=3000, score=0.729, total=   0.0s
# [CV] gamma=25, learning_rate=0.0001, n_estimator=10 ..................
# [CV]  gamma=25, learning_rate=0.0001, n_estimator=10, score=0.673, total=   0.0s
# [CV] gamma=25, learning_rate=0.0001, n_estimator=10 ..................
# [CV]  gamma=25, learning_rate=0.0001, n_estimator=10, score=0.714, total=   0.0s
# [CV] gamma=25, learning_rate=0.0001, n_estimator=10 ..................
# [CV]  gamma=25, learning_rate=0.0001, n_estimator=10, score=0.688, total=   0.0s
# [CV] gamma=25, learning_rate=0.0001, n_estimator=10 ..................
# [CV]  gamma=25, learning_rate=0.0001, n_estimator=10, score=0.771, total=   0.0s
# [CV] gamma=25, learning_rate=0.0001, n_estimator=10 ..................
# [CV]  gamma=25, learning_rate=0.0001, n_estimator=10, score=0.729, total=   0.0s
# [CV] gamma=25, learning_rate=0.0001, n_estimator=100 .................
# [CV]  gamma=25, learning_rate=0.0001, n_estimator=100, score=0.673, total=   0.0s
# [CV] gamma=25, learning_rate=0.0001, n_estimator=100 .................
# [CV]  gamma=25, learning_rate=0.0001, n_estimator=100, score=0.714, total=   0.0s
# [CV] gamma=25, learning_rate=0.0001, n_estimator=100 .................
# [CV]  gamma=25, learning_rate=0.0001, n_estimator=100, score=0.688, total=   0.0s
# [CV] gamma=25, learning_rate=0.0001, n_estimator=100 .................
# [CV]  gamma=25, learning_rate=0.0001, n_estimator=100, score=0.771, total=   0.0s
# [CV] gamma=25, learning_rate=0.0001, n_estimator=100 .................
# [CV]  gamma=25, learning_rate=0.0001, n_estimator=100, score=0.729, total=   0.0s
# [CV] gamma=25, learning_rate=0.0001, n_estimator=1000 ................
# [CV]  gamma=25, learning_rate=0.0001, n_estimator=1000, score=0.673, total=   0.0s
# [CV] gamma=25, learning_rate=0.0001, n_estimator=1000 ................
# [CV]  gamma=25, learning_rate=0.0001, n_estimator=1000, score=0.714, total=   0.0s
# [CV] gamma=25, learning_rate=0.0001, n_estimator=1000 ................
# [CV]  gamma=25, learning_rate=0.0001, n_estimator=1000, score=0.688, total=   0.0s
# [CV] gamma=25, learning_rate=0.0001, n_estimator=1000 ................
# [CV]  gamma=25, learning_rate=0.0001, n_estimator=1000, score=0.771, total=   0.0s
# [CV] gamma=25, learning_rate=0.0001, n_estimator=1000 ................
# [CV]  gamma=25, learning_rate=0.0001, n_estimator=1000, score=0.729, total=   0.0s
# [CV] gamma=25, learning_rate=0.0001, n_estimator=2000 ................
# [CV]  gamma=25, learning_rate=0.0001, n_estimator=2000, score=0.673, total=   0.0s
# [CV] gamma=25, learning_rate=0.0001, n_estimator=2000 ................
# [CV]  gamma=25, learning_rate=0.0001, n_estimator=2000, score=0.714, total=   0.0s
# [CV] gamma=25, learning_rate=0.0001, n_estimator=2000 ................
# [CV]  gamma=25, learning_rate=0.0001, n_estimator=2000, score=0.688, total=   0.0s
# [CV] gamma=25, learning_rate=0.0001, n_estimator=2000 ................
# [CV]  gamma=25, learning_rate=0.0001, n_estimator=2000, score=0.771, total=   0.0s
# [CV] gamma=25, learning_rate=0.0001, n_estimator=2000 ................
# [CV]  gamma=25, learning_rate=0.0001, n_estimator=2000, score=0.729, total=   0.0s
# [CV] gamma=25, learning_rate=0.0001, n_estimator=3000 ................
# [CV]  gamma=25, learning_rate=0.0001, n_estimator=3000, score=0.673, total=   0.0s
# [CV] gamma=25, learning_rate=0.0001, n_estimator=3000 ................
# [CV]  gamma=25, learning_rate=0.0001, n_estimator=3000, score=0.714, total=   0.0s
# [CV] gamma=25, learning_rate=0.0001, n_estimator=3000 ................
# [CV]  gamma=25, learning_rate=0.0001, n_estimator=3000, score=0.688, total=   0.0s
# [CV] gamma=25, learning_rate=0.0001, n_estimator=3000 ................
# [CV]  gamma=25, learning_rate=0.0001, n_estimator=3000, score=0.771, total=   0.0s
# [CV] gamma=25, learning_rate=0.0001, n_estimator=3000 ................
# [CV]  gamma=25, learning_rate=0.0001, n_estimator=3000, score=0.729, total=   0.0s
# [CV] gamma=12, learning_rate=0.1, n_estimator=10 .....................
# [CV]  gamma=12, learning_rate=0.1, n_estimator=10, score=0.755, total=   0.0s
# [CV] gamma=12, learning_rate=0.1, n_estimator=10 .....................
# [CV]  gamma=12, learning_rate=0.1, n_estimator=10, score=0.816, total=   0.0s
# [CV] gamma=12, learning_rate=0.1, n_estimator=10 .....................
# [CV]  gamma=12, learning_rate=0.1, n_estimator=10, score=0.812, total=   0.0s
# [CV] gamma=12, learning_rate=0.1, n_estimator=10 .....................
# [CV]  gamma=12, learning_rate=0.1, n_estimator=10, score=0.833, total=   0.0s
# [CV] gamma=12, learning_rate=0.1, n_estimator=10 .....................
# [CV]  gamma=12, learning_rate=0.1, n_estimator=10, score=0.812, total=   0.0s
# [CV] gamma=12, learning_rate=0.1, n_estimator=100 ....................
# [CV]  gamma=12, learning_rate=0.1, n_estimator=100, score=0.755, total=   0.0s
# [CV] gamma=12, learning_rate=0.1, n_estimator=100 ....................
# [CV]  gamma=12, learning_rate=0.1, n_estimator=100, score=0.816, total=   0.0s
# [CV] gamma=12, learning_rate=0.1, n_estimator=100 ....................
# [CV]  gamma=12, learning_rate=0.1, n_estimator=100, score=0.812, total=   0.0s
# [CV] gamma=12, learning_rate=0.1, n_estimator=100 ....................
# [CV]  gamma=12, learning_rate=0.1, n_estimator=100, score=0.833, total=   0.0s
# [CV] gamma=12, learning_rate=0.1, n_estimator=100 ....................
# [CV]  gamma=12, learning_rate=0.1, n_estimator=100, score=0.812, total=   0.0s
# [CV] gamma=12, learning_rate=0.1, n_estimator=1000 ...................
# [CV]  gamma=12, learning_rate=0.1, n_estimator=1000, score=0.755, total=   0.0s
# [CV] gamma=12, learning_rate=0.1, n_estimator=1000 ...................
# [CV]  gamma=12, learning_rate=0.1, n_estimator=1000, score=0.816, total=   0.0s
# [CV] gamma=12, learning_rate=0.1, n_estimator=1000 ...................
# [CV]  gamma=12, learning_rate=0.1, n_estimator=1000, score=0.812, total=   0.0s
# [CV] gamma=12, learning_rate=0.1, n_estimator=1000 ...................
# [CV]  gamma=12, learning_rate=0.1, n_estimator=1000, score=0.833, total=   0.0s
# [CV] gamma=12, learning_rate=0.1, n_estimator=1000 ...................
# [CV]  gamma=12, learning_rate=0.1, n_estimator=1000, score=0.812, total=   0.0s
# [CV] gamma=12, learning_rate=0.1, n_estimator=2000 ...................
# [CV]  gamma=12, learning_rate=0.1, n_estimator=2000, score=0.755, total=   0.0s
# [CV] gamma=12, learning_rate=0.1, n_estimator=2000 ...................
# [CV]  gamma=12, learning_rate=0.1, n_estimator=2000, score=0.816, total=   0.0s
# [CV] gamma=12, learning_rate=0.1, n_estimator=2000 ...................
# [CV]  gamma=12, learning_rate=0.1, n_estimator=2000, score=0.812, total=   0.0s
# [CV] gamma=12, learning_rate=0.1, n_estimator=2000 ...................
# [CV]  gamma=12, learning_rate=0.1, n_estimator=2000, score=0.833, total=   0.0s
# [CV] gamma=12, learning_rate=0.1, n_estimator=2000 ...................
# [CV]  gamma=12, learning_rate=0.1, n_estimator=2000, score=0.812, total=   0.0s
# [CV] gamma=12, learning_rate=0.1, n_estimator=3000 ...................
# [CV]  gamma=12, learning_rate=0.1, n_estimator=3000, score=0.755, total=   0.0s
# [CV] gamma=12, learning_rate=0.1, n_estimator=3000 ...................
# [CV]  gamma=12, learning_rate=0.1, n_estimator=3000, score=0.816, total=   0.0s
# [CV] gamma=12, learning_rate=0.1, n_estimator=3000 ...................
# [CV]  gamma=12, learning_rate=0.1, n_estimator=3000, score=0.812, total=   0.0s
# [CV] gamma=12, learning_rate=0.1, n_estimator=3000 ...................
# [CV]  gamma=12, learning_rate=0.1, n_estimator=3000, score=0.833, total=   0.0s
# [CV] gamma=12, learning_rate=0.1, n_estimator=3000 ...................
# [CV]  gamma=12, learning_rate=0.1, n_estimator=3000, score=0.812, total=   0.0s
# [CV] gamma=12, learning_rate=0.01, n_estimator=10 ....................
# [CV]  gamma=12, learning_rate=0.01, n_estimator=10, score=0.755, total=   0.0s
# [CV] gamma=12, learning_rate=0.01, n_estimator=10 ....................
# [CV]  gamma=12, learning_rate=0.01, n_estimator=10, score=0.796, total=   0.0s
# [CV] gamma=12, learning_rate=0.01, n_estimator=10 ....................
# [CV]  gamma=12, learning_rate=0.01, n_estimator=10, score=0.812, total=   0.0s
# [CV] gamma=12, learning_rate=0.01, n_estimator=10 ....................
# [CV]  gamma=12, learning_rate=0.01, n_estimator=10, score=0.833, total=   0.0s
# [CV] gamma=12, learning_rate=0.01, n_estimator=10 ....................
# [CV]  gamma=12, learning_rate=0.01, n_estimator=10, score=0.812, total=   0.0s
# [CV] gamma=12, learning_rate=0.01, n_estimator=100 ...................
# [CV]  gamma=12, learning_rate=0.01, n_estimator=100, score=0.755, total=   0.0s
# [CV] gamma=12, learning_rate=0.01, n_estimator=100 ...................
# [CV]  gamma=12, learning_rate=0.01, n_estimator=100, score=0.796, total=   0.0s
# [CV] gamma=12, learning_rate=0.01, n_estimator=100 ...................
# [CV]  gamma=12, learning_rate=0.01, n_estimator=100, score=0.812, total=   0.0s
# [CV] gamma=12, learning_rate=0.01, n_estimator=100 ...................
# [CV]  gamma=12, learning_rate=0.01, n_estimator=100, score=0.833, total=   0.0s
# [CV] gamma=12, learning_rate=0.01, n_estimator=100 ...................
# [CV]  gamma=12, learning_rate=0.01, n_estimator=100, score=0.812, total=   0.0s
# [CV] gamma=12, learning_rate=0.01, n_estimator=1000 ..................
# [CV]  gamma=12, learning_rate=0.01, n_estimator=1000, score=0.755, total=   0.0s
# [CV] gamma=12, learning_rate=0.01, n_estimator=1000 ..................
# [CV]  gamma=12, learning_rate=0.01, n_estimator=1000, score=0.796, total=   0.0s
# [CV] gamma=12, learning_rate=0.01, n_estimator=1000 ..................
# [CV]  gamma=12, learning_rate=0.01, n_estimator=1000, score=0.812, total=   0.0s
# [CV] gamma=12, learning_rate=0.01, n_estimator=1000 ..................
# [CV]  gamma=12, learning_rate=0.01, n_estimator=1000, score=0.833, total=   0.0s
# [CV] gamma=12, learning_rate=0.01, n_estimator=1000 ..................
# [CV]  gamma=12, learning_rate=0.01, n_estimator=1000, score=0.812, total=   0.0s
# [CV] gamma=12, learning_rate=0.01, n_estimator=2000 ..................
# [CV]  gamma=12, learning_rate=0.01, n_estimator=2000, score=0.755, total=   0.0s
# [CV] gamma=12, learning_rate=0.01, n_estimator=2000 ..................
# [CV]  gamma=12, learning_rate=0.01, n_estimator=2000, score=0.796, total=   0.0s
# [CV] gamma=12, learning_rate=0.01, n_estimator=2000 ..................
# [CV]  gamma=12, learning_rate=0.01, n_estimator=2000, score=0.812, total=   0.0s
# [CV] gamma=12, learning_rate=0.01, n_estimator=2000 ..................
# [CV]  gamma=12, learning_rate=0.01, n_estimator=2000, score=0.833, total=   0.0s
# [CV] gamma=12, learning_rate=0.01, n_estimator=2000 ..................
# [CV]  gamma=12, learning_rate=0.01, n_estimator=2000, score=0.812, total=   0.0s
# [CV] gamma=12, learning_rate=0.01, n_estimator=3000 ..................
# [CV]  gamma=12, learning_rate=0.01, n_estimator=3000, score=0.755, total=   0.0s
# [CV] gamma=12, learning_rate=0.01, n_estimator=3000 ..................
# [CV]  gamma=12, learning_rate=0.01, n_estimator=3000, score=0.796, total=   0.0s
# [CV] gamma=12, learning_rate=0.01, n_estimator=3000 ..................
# [CV]  gamma=12, learning_rate=0.01, n_estimator=3000, score=0.812, total=   0.0s
# [CV] gamma=12, learning_rate=0.01, n_estimator=3000 ..................
# [CV]  gamma=12, learning_rate=0.01, n_estimator=3000, score=0.833, total=   0.0s
# [CV] gamma=12, learning_rate=0.01, n_estimator=3000 ..................
# [CV]  gamma=12, learning_rate=0.01, n_estimator=3000, score=0.812, total=   0.0s
# [CV] gamma=12, learning_rate=0.001, n_estimator=10 ...................
# [CV]  gamma=12, learning_rate=0.001, n_estimator=10, score=0.755, total=   0.0s
# [CV] gamma=12, learning_rate=0.001, n_estimator=10 ...................
# [CV]  gamma=12, learning_rate=0.001, n_estimator=10, score=0.755, total=   0.0s
# [CV] gamma=12, learning_rate=0.001, n_estimator=10 ...................
# [CV]  gamma=12, learning_rate=0.001, n_estimator=10, score=0.646, total=   0.0s
# [CV] gamma=12, learning_rate=0.001, n_estimator=10 ...................
# [CV]  gamma=12, learning_rate=0.001, n_estimator=10, score=0.771, total=   0.0s
# [CV] gamma=12, learning_rate=0.001, n_estimator=10 ...................
# [CV]  gamma=12, learning_rate=0.001, n_estimator=10, score=0.750, total=   0.0s
# [CV] gamma=12, learning_rate=0.001, n_estimator=100 ..................
# [CV]  gamma=12, learning_rate=0.001, n_estimator=100, score=0.755, total=   0.0s
# [CV] gamma=12, learning_rate=0.001, n_estimator=100 ..................
# [CV]  gamma=12, learning_rate=0.001, n_estimator=100, score=0.755, total=   0.0s
# [CV] gamma=12, learning_rate=0.001, n_estimator=100 ..................
# [CV]  gamma=12, learning_rate=0.001, n_estimator=100, score=0.646, total=   0.0s
# [CV] gamma=12, learning_rate=0.001, n_estimator=100 ..................
# [CV]  gamma=12, learning_rate=0.001, n_estimator=100, score=0.771, total=   0.0s
# [CV] gamma=12, learning_rate=0.001, n_estimator=100 ..................
# [CV]  gamma=12, learning_rate=0.001, n_estimator=100, score=0.750, total=   0.0s
# [CV] gamma=12, learning_rate=0.001, n_estimator=1000 .................
# [CV]  gamma=12, learning_rate=0.001, n_estimator=1000, score=0.755, total=   0.0s
# [CV] gamma=12, learning_rate=0.001, n_estimator=1000 .................
# [CV]  gamma=12, learning_rate=0.001, n_estimator=1000, score=0.755, total=   0.0s
# [CV] gamma=12, learning_rate=0.001, n_estimator=1000 .................
# [CV]  gamma=12, learning_rate=0.001, n_estimator=1000, score=0.646, total=   0.0s
# [CV] gamma=12, learning_rate=0.001, n_estimator=1000 .................
# [CV]  gamma=12, learning_rate=0.001, n_estimator=1000, score=0.771, total=   0.0s
# [CV] gamma=12, learning_rate=0.001, n_estimator=1000 .................
# [CV]  gamma=12, learning_rate=0.001, n_estimator=1000, score=0.750, total=   0.0s
# [CV] gamma=12, learning_rate=0.001, n_estimator=2000 .................
# [CV]  gamma=12, learning_rate=0.001, n_estimator=2000, score=0.755, total=   0.0s
# [CV] gamma=12, learning_rate=0.001, n_estimator=2000 .................
# [CV]  gamma=12, learning_rate=0.001, n_estimator=2000, score=0.755, total=   0.0s
# [CV] gamma=12, learning_rate=0.001, n_estimator=2000 .................
# [CV]  gamma=12, learning_rate=0.001, n_estimator=2000, score=0.646, total=   0.0s
# [CV] gamma=12, learning_rate=0.001, n_estimator=2000 .................
# [CV]  gamma=12, learning_rate=0.001, n_estimator=2000, score=0.771, total=   0.0s
# [CV] gamma=12, learning_rate=0.001, n_estimator=2000 .................
# [CV]  gamma=12, learning_rate=0.001, n_estimator=2000, score=0.750, total=   0.0s
# [CV] gamma=12, learning_rate=0.001, n_estimator=3000 .................
# [CV]  gamma=12, learning_rate=0.001, n_estimator=3000, score=0.755, total=   0.0s
# [CV] gamma=12, learning_rate=0.001, n_estimator=3000 .................
# [CV]  gamma=12, learning_rate=0.001, n_estimator=3000, score=0.755, total=   0.0s
# [CV] gamma=12, learning_rate=0.001, n_estimator=3000 .................
# [CV]  gamma=12, learning_rate=0.001, n_estimator=3000, score=0.646, total=   0.0s
# [CV] gamma=12, learning_rate=0.001, n_estimator=3000 .................
# [CV]  gamma=12, learning_rate=0.001, n_estimator=3000, score=0.771, total=   0.0s
# [CV] gamma=12, learning_rate=0.001, n_estimator=3000 .................
# [CV]  gamma=12, learning_rate=0.001, n_estimator=3000, score=0.750, total=   0.0s
# [CV] gamma=12, learning_rate=0.0001, n_estimator=10 ..................
# [CV]  gamma=12, learning_rate=0.0001, n_estimator=10, score=0.694, total=   0.0s
# [CV] gamma=12, learning_rate=0.0001, n_estimator=10 ..................
# [CV]  gamma=12, learning_rate=0.0001, n_estimator=10, score=0.735, total=   0.0s
# [CV] gamma=12, learning_rate=0.0001, n_estimator=10 ..................
# [CV]  gamma=12, learning_rate=0.0001, n_estimator=10, score=0.646, total=   0.0s
# [CV] gamma=12, learning_rate=0.0001, n_estimator=10 ..................
# [CV]  gamma=12, learning_rate=0.0001, n_estimator=10, score=0.771, total=   0.0s
# [CV] gamma=12, learning_rate=0.0001, n_estimator=10 ..................
# [CV]  gamma=12, learning_rate=0.0001, n_estimator=10, score=0.750, total=   0.0s
# [CV] gamma=12, learning_rate=0.0001, n_estimator=100 .................
# [CV]  gamma=12, learning_rate=0.0001, n_estimator=100, score=0.694, total=   0.0s
# [CV] gamma=12, learning_rate=0.0001, n_estimator=100 .................
# [CV]  gamma=12, learning_rate=0.0001, n_estimator=100, score=0.735, total=   0.0s
# [CV] gamma=12, learning_rate=0.0001, n_estimator=100 .................
# [CV]  gamma=12, learning_rate=0.0001, n_estimator=100, score=0.646, total=   0.0s
# [CV] gamma=12, learning_rate=0.0001, n_estimator=100 .................
# [CV]  gamma=12, learning_rate=0.0001, n_estimator=100, score=0.771, total=   0.0s
# [CV] gamma=12, learning_rate=0.0001, n_estimator=100 .................
# [CV]  gamma=12, learning_rate=0.0001, n_estimator=100, score=0.750, total=   0.0s
# [CV] gamma=12, learning_rate=0.0001, n_estimator=1000 ................
# [CV]  gamma=12, learning_rate=0.0001, n_estimator=1000, score=0.694, total=   0.0s
# [CV] gamma=12, learning_rate=0.0001, n_estimator=1000 ................
# [CV]  gamma=12, learning_rate=0.0001, n_estimator=1000, score=0.735, total=   0.0s
# [CV] gamma=12, learning_rate=0.0001, n_estimator=1000 ................
# [CV]  gamma=12, learning_rate=0.0001, n_estimator=1000, score=0.646, total=   0.0s
# [CV] gamma=12, learning_rate=0.0001, n_estimator=1000 ................
# [CV]  gamma=12, learning_rate=0.0001, n_estimator=1000, score=0.771, total=   0.0s
# [CV] gamma=12, learning_rate=0.0001, n_estimator=1000 ................
# [CV]  gamma=12, learning_rate=0.0001, n_estimator=1000, score=0.750, total=   0.0s
# [CV] gamma=12, learning_rate=0.0001, n_estimator=2000 ................
# [CV]  gamma=12, learning_rate=0.0001, n_estimator=2000, score=0.694, total=   0.0s
# [CV] gamma=12, learning_rate=0.0001, n_estimator=2000 ................
# [CV]  gamma=12, learning_rate=0.0001, n_estimator=2000, score=0.735, total=   0.0s
# [CV] gamma=12, learning_rate=0.0001, n_estimator=2000 ................
# [CV]  gamma=12, learning_rate=0.0001, n_estimator=2000, score=0.646, total=   0.0s
# [CV] gamma=12, learning_rate=0.0001, n_estimator=2000 ................
# [CV]  gamma=12, learning_rate=0.0001, n_estimator=2000, score=0.771, total=   0.0s
# [CV] gamma=12, learning_rate=0.0001, n_estimator=2000 ................
# [CV]  gamma=12, learning_rate=0.0001, n_estimator=2000, score=0.750, total=   0.0s
# [CV] gamma=12, learning_rate=0.0001, n_estimator=3000 ................
# [CV]  gamma=12, learning_rate=0.0001, n_estimator=3000, score=0.694, total=   0.0s
# [CV] gamma=12, learning_rate=0.0001, n_estimator=3000 ................
# [CV]  gamma=12, learning_rate=0.0001, n_estimator=3000, score=0.735, total=   0.0s
# [CV] gamma=12, learning_rate=0.0001, n_estimator=3000 ................
# [CV]  gamma=12, learning_rate=0.0001, n_estimator=3000, score=0.646, total=   0.0s
# [CV] gamma=12, learning_rate=0.0001, n_estimator=3000 ................
# [CV]  gamma=12, learning_rate=0.0001, n_estimator=3000, score=0.771, total=   0.0s
# [CV] gamma=12, learning_rate=0.0001, n_estimator=3000 ................
# [CV]  gamma=12, learning_rate=0.0001, n_estimator=3000, score=0.750, total=   0.0s
# [CV] gamma=10, learning_rate=0.1, n_estimator=10 .....................
# [CV]  gamma=10, learning_rate=0.1, n_estimator=10, score=0.755, total=   0.0s
# [CV] gamma=10, learning_rate=0.1, n_estimator=10 .....................
# [CV]  gamma=10, learning_rate=0.1, n_estimator=10, score=0.816, total=   0.0s
# [CV] gamma=10, learning_rate=0.1, n_estimator=10 .....................
# [CV]  gamma=10, learning_rate=0.1, n_estimator=10, score=0.812, total=   0.0s
# [CV] gamma=10, learning_rate=0.1, n_estimator=10 .....................
# [CV]  gamma=10, learning_rate=0.1, n_estimator=10, score=0.833, total=   0.0s
# [CV] gamma=10, learning_rate=0.1, n_estimator=10 .....................
# [CV]  gamma=10, learning_rate=0.1, n_estimator=10, score=0.792, total=   0.0s
# [CV] gamma=10, learning_rate=0.1, n_estimator=100 ....................
# [CV]  gamma=10, learning_rate=0.1, n_estimator=100, score=0.755, total=   0.0s
# [CV] gamma=10, learning_rate=0.1, n_estimator=100 ....................
# [CV]  gamma=10, learning_rate=0.1, n_estimator=100, score=0.816, total=   0.0s
# [CV] gamma=10, learning_rate=0.1, n_estimator=100 ....................
# [CV]  gamma=10, learning_rate=0.1, n_estimator=100, score=0.812, total=   0.0s
# [CV] gamma=10, learning_rate=0.1, n_estimator=100 ....................
# [CV]  gamma=10, learning_rate=0.1, n_estimator=100, score=0.833, total=   0.0s
# [CV] gamma=10, learning_rate=0.1, n_estimator=100 ....................
# [CV]  gamma=10, learning_rate=0.1, n_estimator=100, score=0.792, total=   0.0s
# [CV] gamma=10, learning_rate=0.1, n_estimator=1000 ...................
# [CV]  gamma=10, learning_rate=0.1, n_estimator=1000, score=0.755, total=   0.0s
# [CV] gamma=10, learning_rate=0.1, n_estimator=1000 ...................
# [CV]  gamma=10, learning_rate=0.1, n_estimator=1000, score=0.816, total=   0.0s
# [CV] gamma=10, learning_rate=0.1, n_estimator=1000 ...................
# [CV]  gamma=10, learning_rate=0.1, n_estimator=1000, score=0.812, total=   0.0s
# [CV] gamma=10, learning_rate=0.1, n_estimator=1000 ...................
# [CV]  gamma=10, learning_rate=0.1, n_estimator=1000, score=0.833, total=   0.0s
# ...
# [CV] gamma=1, learning_rate=0.1, n_estimator=10 ......................
# [CV]  gamma=1, learning_rate=0.1, n_estimator=10, score=0.792, total=   0.0s
# [CV] gamma=1, learning_rate=0.1, n_estimator=100 .....................
# [CV]  gamma=1, learning_rate=0.1, n_estimator=100, score=0.816, total=   0.0s
# [CV] gamma=1, learning_rate=0.1, n_estimator=100 .....................
# [CV]  gamma=1, learning_rate=0.1, n_estimator=100, score=0.816, total=   0.0s
# [CV] gamma=1, learning_rate=0.1, n_estimator=100 .....................
# [CV]  gamma=1, learning_rate=0.1, n_estimator=100, score=0.792, total=   0.0s
# [CV] gamma=1, learning_rate=0.1, n_estimator=100 .....................
# [CV]  gamma=1, learning_rate=0.1, n_estimator=100, score=0.750, total=   0.0s
# [CV] gamma=1, learning_rate=0.1, n_estimator=100 .....................
# [CV]  gamma=1, learning_rate=0.1, n_estimator=100, score=0.792, total=   0.0s
# [CV] gamma=1, learning_rate=0.1, n_estimator=1000 ....................
# [CV]  gamma=1, learning_rate=0.1, n_estimator=1000, score=0.816, total=   0.0s
# [CV] gamma=1, learning_rate=0.1, n_estimator=1000 ....................
# [CV]  gamma=1, learning_rate=0.1, n_estimator=1000, score=0.816, total=   0.0s
# [CV] gamma=1, learning_rate=0.1, n_estimator=1000 ....................
# [CV]  gamma=1, learning_rate=0.1, n_estimator=1000, score=0.792, total=   0.0s
# [CV] gamma=1, learning_rate=0.1, n_estimator=1000 ....................
# [CV]  gamma=1, learning_rate=0.1, n_estimator=1000, score=0.750, total=   0.0s
# [CV] gamma=1, learning_rate=0.1, n_estimator=1000 ....................
# [CV]  gamma=1, learning_rate=0.1, n_estimator=1000, score=0.792, total=   0.0s
# [CV] gamma=1, learning_rate=0.1, n_estimator=2000 ....................
# [CV]  gamma=1, learning_rate=0.1, n_estimator=2000, score=0.816, total=   0.0s
# [CV] gamma=1, learning_rate=0.1, n_estimator=2000 ....................
# [CV]  gamma=1, learning_rate=0.1, n_estimator=2000, score=0.816, total=   0.0s
# [CV] gamma=1, learning_rate=0.1, n_estimator=2000 ....................
# [CV]  gamma=1, learning_rate=0.1, n_estimator=2000, score=0.792, total=   0.0s
# [CV] gamma=1, learning_rate=0.1, n_estimator=2000 ....................
# [CV]  gamma=1, learning_rate=0.1, n_estimator=2000, score=0.750, total=   0.0s
# [CV] gamma=1, learning_rate=0.1, n_estimator=2000 ....................
# [CV]  gamma=1, learning_rate=0.1, n_estimator=2000, score=0.792, total=   0.0s
# [CV] gamma=1, learning_rate=0.1, n_estimator=3000 ....................
# [CV]  gamma=1, learning_rate=0.1, n_estimator=3000, score=0.816, total=   0.0s
# [CV] gamma=1, learning_rate=0.1, n_estimator=3000 ....................
# [CV]  gamma=1, learning_rate=0.1, n_estimator=3000, score=0.816, total=   0.0s
# [CV] gamma=1, learning_rate=0.1, n_estimator=3000 ....................
# [CV]  gamma=1, learning_rate=0.1, n_estimator=3000, score=0.792, total=   0.0s
# [CV] gamma=1, learning_rate=0.1, n_estimator=3000 ....................
# [CV]  gamma=1, learning_rate=0.1, n_estimator=3000, score=0.750, total=   0.0s
# [CV] gamma=1, learning_rate=0.1, n_estimator=3000 ....................
# [CV]  gamma=1, learning_rate=0.1, n_estimator=3000, score=0.792, total=   0.0s
# [CV] gamma=1, learning_rate=0.01, n_estimator=10 .....................
# [CV]  gamma=1, learning_rate=0.01, n_estimator=10, score=0.776, total=   0.0s
# [CV] gamma=1, learning_rate=0.01, n_estimator=10 .....................
# [CV]  gamma=1, learning_rate=0.01, n_estimator=10, score=0.776, total=   0.0s
# [CV] gamma=1, learning_rate=0.01, n_estimator=10 .....................
# [CV]  gamma=1, learning_rate=0.01, n_estimator=10, score=0.792, total=   0.0s
# [CV] gamma=1, learning_rate=0.01, n_estimator=10 .....................
# [CV]  gamma=1, learning_rate=0.01, n_estimator=10, score=0.792, total=   0.0s
# [CV] gamma=1, learning_rate=0.01, n_estimator=10 .....................
# [CV]  gamma=1, learning_rate=0.01, n_estimator=10, score=0.771, total=   0.0s
# [CV] gamma=1, learning_rate=0.01, n_estimator=100 ....................
# [CV]  gamma=1, learning_rate=0.01, n_estimator=100, score=0.776, total=   0.0s
# [CV] gamma=1, learning_rate=0.01, n_estimator=100 ....................
# [CV]  gamma=1, learning_rate=0.01, n_estimator=100, score=0.776, total=   0.0s
# [CV] gamma=1, learning_rate=0.01, n_estimator=100 ....................
# [CV]  gamma=1, learning_rate=0.01, n_estimator=100, score=0.792, total=   0.0s
# [CV] gamma=1, learning_rate=0.01, n_estimator=100 ....................
# [CV]  gamma=1, learning_rate=0.01, n_estimator=100, score=0.792, total=   0.0s
# [CV] gamma=1, learning_rate=0.01, n_estimator=100 ....................
# [CV]  gamma=1, learning_rate=0.01, n_estimator=100, score=0.771, total=   0.0s
# [CV] gamma=1, learning_rate=0.01, n_estimator=1000 ...................
# [CV]  gamma=1, learning_rate=0.01, n_estimator=1000, score=0.776, total=   0.0s
# [CV] gamma=1, learning_rate=0.01, n_estimator=1000 ...................
# [CV]  gamma=1, learning_rate=0.01, n_estimator=1000, score=0.776, total=   0.0s
# [CV] gamma=1, learning_rate=0.01, n_estimator=1000 ...................
# [CV]  gamma=1, learning_rate=0.01, n_estimator=1000, score=0.792, total=   0.0s
# [CV] gamma=1, learning_rate=0.01, n_estimator=1000 ...................
# [CV]  gamma=1, learning_rate=0.01, n_estimator=1000, score=0.792, total=   0.0s
# [CV] gamma=1, learning_rate=0.01, n_estimator=1000 ...................
# [CV]  gamma=1, learning_rate=0.01, n_estimator=1000, score=0.771, total=   0.0s
# [CV] gamma=1, learning_rate=0.01, n_estimator=2000 ...................
# [CV]  gamma=1, learning_rate=0.01, n_estimator=2000, score=0.776, total=   0.0s
# [CV] gamma=1, learning_rate=0.01, n_estimator=2000 ...................
# [CV]  gamma=1, learning_rate=0.01, n_estimator=2000, score=0.776, total=   0.0s
# [CV] gamma=1, learning_rate=0.01, n_estimator=2000 ...................
# [CV]  gamma=1, learning_rate=0.01, n_estimator=2000, score=0.792, total=   0.0s
# [CV] gamma=1, learning_rate=0.01, n_estimator=2000 ...................
# [CV]  gamma=1, learning_rate=0.01, n_estimator=2000, score=0.792, total=   0.0s
# [CV] gamma=1, learning_rate=0.01, n_estimator=2000 ...................
# [CV]  gamma=1, learning_rate=0.01, n_estimator=2000, score=0.771, total=   0.0s
# [CV] gamma=1, learning_rate=0.01, n_estimator=3000 ...................
# [CV]  gamma=1, learning_rate=0.01, n_estimator=3000, score=0.776, total=   0.0s
# [CV] gamma=1, learning_rate=0.01, n_estimator=3000 ...................
# [CV]  gamma=1, learning_rate=0.01, n_estimator=3000, score=0.776, total=   0.0s
# [CV] gamma=1, learning_rate=0.01, n_estimator=3000 ...................
# [CV]  gamma=1, learning_rate=0.01, n_estimator=3000, score=0.792, total=   0.0s
# [CV] gamma=1, learning_rate=0.01, n_estimator=3000 ...................
# [CV]  gamma=1, learning_rate=0.01, n_estimator=3000, score=0.792, total=   0.0s
# [CV] gamma=1, learning_rate=0.01, n_estimator=3000 ...................
# [CV]  gamma=1, learning_rate=0.01, n_estimator=3000, score=0.771, total=   0.0s
# [CV] gamma=1, learning_rate=0.001, n_estimator=10 ....................
# [CV]  gamma=1, learning_rate=0.001, n_estimator=10, score=0.816, total=   0.0s
# [CV] gamma=1, learning_rate=0.001, n_estimator=10 ....................
# [CV]  gamma=1, learning_rate=0.001, n_estimator=10, score=0.755, total=   0.0s
# [CV] gamma=1, learning_rate=0.001, n_estimator=10 ....................
# [CV]  gamma=1, learning_rate=0.001, n_estimator=10, score=0.771, total=   0.0s
# [CV] gamma=1, learning_rate=0.001, n_estimator=10 ....................
# [CV]  gamma=1, learning_rate=0.001, n_estimator=10, score=0.833, total=   0.0s
# [CV] gamma=1, learning_rate=0.001, n_estimator=10 ....................
# [CV]  gamma=1, learning_rate=0.001, n_estimator=10, score=0.750, total=   0.0s
# [CV] gamma=1, learning_rate=0.001, n_estimator=100 ...................
# [CV]  gamma=1, learning_rate=0.001, n_estimator=100, score=0.816, total=   0.0s
# [CV] gamma=1, learning_rate=0.001, n_estimator=100 ...................
# [CV]  gamma=1, learning_rate=0.001, n_estimator=100, score=0.755, total=   0.0s
# [CV] gamma=1, learning_rate=0.001, n_estimator=100 ...................
# [CV]  gamma=1, learning_rate=0.001, n_estimator=100, score=0.771, total=   0.0s
# [CV] gamma=1, learning_rate=0.001, n_estimator=100 ...................
# [CV]  gamma=1, learning_rate=0.001, n_estimator=100, score=0.833, total=   0.0s
# [CV] gamma=1, learning_rate=0.001, n_estimator=100 ...................
# [CV]  gamma=1, learning_rate=0.001, n_estimator=100, score=0.750, total=   0.0s
# [CV] gamma=1, learning_rate=0.001, n_estimator=1000 ..................
# [CV]  gamma=1, learning_rate=0.001, n_estimator=1000, score=0.816, total=   0.0s
# [CV] gamma=1, learning_rate=0.001, n_estimator=1000 ..................
# [CV]  gamma=1, learning_rate=0.001, n_estimator=1000, score=0.755, total=   0.0s
# [CV] gamma=1, learning_rate=0.001, n_estimator=1000 ..................
# [CV]  gamma=1, learning_rate=0.001, n_estimator=1000, score=0.771, total=   0.0s
# [CV] gamma=1, learning_rate=0.001, n_estimator=1000 ..................
# [CV]  gamma=1, learning_rate=0.001, n_estimator=1000, score=0.833, total=   0.0s
# [CV] gamma=1, learning_rate=0.001, n_estimator=1000 ..................
# [CV]  gamma=1, learning_rate=0.001, n_estimator=1000, score=0.750, total=   0.0s
# [CV] gamma=1, learning_rate=0.001, n_estimator=2000 ..................
# [CV]  gamma=1, learning_rate=0.001, n_estimator=2000, score=0.816, total=   0.0s
# [CV] gamma=1, learning_rate=0.001, n_estimator=2000 ..................
# [CV]  gamma=1, learning_rate=0.001, n_estimator=2000, score=0.755, total=   0.0s
# [CV] gamma=1, learning_rate=0.001, n_estimator=2000 ..................
# [CV]  gamma=1, learning_rate=0.001, n_estimator=2000, score=0.771, total=   0.0s
# [CV] gamma=1, learning_rate=0.001, n_estimator=2000 ..................
# [CV]  gamma=1, learning_rate=0.001, n_estimator=2000, score=0.833, total=   0.0s
# [CV] gamma=1, learning_rate=0.001, n_estimator=2000 ..................
# [CV]  gamma=1, learning_rate=0.001, n_estimator=2000, score=0.750, total=   0.0s
# [CV] gamma=1, learning_rate=0.001, n_estimator=3000 ..................
# [CV]  gamma=1, learning_rate=0.001, n_estimator=3000, score=0.816, total=   0.0s
# [CV] gamma=1, learning_rate=0.001, n_estimator=3000 ..................
# [CV]  gamma=1, learning_rate=0.001, n_estimator=3000, score=0.755, total=   0.0s
# [CV] gamma=1, learning_rate=0.001, n_estimator=3000 ..................
# [CV]  gamma=1, learning_rate=0.001, n_estimator=3000, score=0.771, total=   0.0s
# [CV] gamma=1, learning_rate=0.001, n_estimator=3000 ..................
# [CV]  gamma=1, learning_rate=0.001, n_estimator=3000, score=0.833, total=   0.0s
# [CV] gamma=1, learning_rate=0.001, n_estimator=3000 ..................
# [CV]  gamma=1, learning_rate=0.001, n_estimator=3000, score=0.750, total=   0.0s
# [CV] gamma=1, learning_rate=0.0001, n_estimator=10 ...................
# [CV]  gamma=1, learning_rate=0.0001, n_estimator=10, score=0.755, total=   0.0s
# [CV] gamma=1, learning_rate=0.0001, n_estimator=10 ...................
# [CV]  gamma=1, learning_rate=0.0001, n_estimator=10, score=0.735, total=   0.0s
# [CV] gamma=1, learning_rate=0.0001, n_estimator=10 ...................
# [CV]  gamma=1, learning_rate=0.0001, n_estimator=10, score=0.771, total=   0.0s
# [CV] gamma=1, learning_rate=0.0001, n_estimator=10 ...................
# [CV]  gamma=1, learning_rate=0.0001, n_estimator=10, score=0.833, total=   0.0s
# [CV] gamma=1, learning_rate=0.0001, n_estimator=10 ...................
# [CV]  gamma=1, learning_rate=0.0001, n_estimator=10, score=0.729, total=   0.0s
# [CV] gamma=1, learning_rate=0.0001, n_estimator=100 ..................
# [CV]  gamma=1, learning_rate=0.0001, n_estimator=100, score=0.755, total=   0.0s
# [CV] gamma=1, learning_rate=0.0001, n_estimator=100 ..................
# [CV]  gamma=1, learning_rate=0.0001, n_estimator=100, score=0.735, total=   0.0s
# [CV] gamma=1, learning_rate=0.0001, n_estimator=100 ..................
# [CV]  gamma=1, learning_rate=0.0001, n_estimator=100, score=0.771, total=   0.0s
# [CV] gamma=1, learning_rate=0.0001, n_estimator=100 ..................
# [CV]  gamma=1, learning_rate=0.0001, n_estimator=100, score=0.833, total=   0.0s
# [CV] gamma=1, learning_rate=0.0001, n_estimator=100 ..................
# [CV]  gamma=1, learning_rate=0.0001, n_estimator=100, score=0.729, total=   0.0s
# [CV] gamma=1, learning_rate=0.0001, n_estimator=1000 .................
# [CV]  gamma=1, learning_rate=0.0001, n_estimator=1000, score=0.755, total=   0.0s
# [CV] gamma=1, learning_rate=0.0001, n_estimator=1000 .................
# [CV]  gamma=1, learning_rate=0.0001, n_estimator=1000, score=0.735, total=   0.0s
# [CV] gamma=1, learning_rate=0.0001, n_estimator=1000 .................
# [CV]  gamma=1, learning_rate=0.0001, n_estimator=1000, score=0.771, total=   0.0s
# [CV] gamma=1, learning_rate=0.0001, n_estimator=1000 .................
# [CV]  gamma=1, learning_rate=0.0001, n_estimator=1000, score=0.833, total=   0.0s
# [CV] gamma=1, learning_rate=0.0001, n_estimator=1000 .................
# [CV]  gamma=1, learning_rate=0.0001, n_estimator=1000, score=0.729, total=   0.0s
# [CV] gamma=1, learning_rate=0.0001, n_estimator=2000 .................
# [CV]  gamma=1, learning_rate=0.0001, n_estimator=2000, score=0.755, total=   0.0s
# [CV] gamma=1, learning_rate=0.0001, n_estimator=2000 .................
# [CV]  gamma=1, learning_rate=0.0001, n_estimator=2000, score=0.735, total=   0.0s
# [CV] gamma=1, learning_rate=0.0001, n_estimator=2000 .................
# [CV]  gamma=1, learning_rate=0.0001, n_estimator=2000, score=0.771, total=   0.0s
# [CV] gamma=1, learning_rate=0.0001, n_estimator=2000 .................
# [CV]  gamma=1, learning_rate=0.0001, n_estimator=2000, score=0.833, total=   0.0s
# [CV] gamma=1, learning_rate=0.0001, n_estimator=2000 .................
# [CV]  gamma=1, learning_rate=0.0001, n_estimator=2000, score=0.729, total=   0.0s
# [CV] gamma=1, learning_rate=0.0001, n_estimator=3000 .................
# [CV]  gamma=1, learning_rate=0.0001, n_estimator=3000, score=0.755, total=   0.0s
# [CV] gamma=1, learning_rate=0.0001, n_estimator=3000 .................
# [CV]  gamma=1, learning_rate=0.0001, n_estimator=3000, score=0.735, total=   0.0s
# [CV] gamma=1, learning_rate=0.0001, n_estimator=3000 .................
# [CV]  gamma=1, learning_rate=0.0001, n_estimator=3000, score=0.771, total=   0.0s
# [CV] gamma=1, learning_rate=0.0001, n_estimator=3000 .................
# [CV]  gamma=1, learning_rate=0.0001, n_estimator=3000, score=0.833, total=   0.0s
# [CV] gamma=1, learning_rate=0.0001, n_estimator=3000 .................
# [CV]  gamma=1, learning_rate=0.0001, n_estimator=3000, score=0.729, total=   0.0s
# [Parallel(n_jobs=1)]: Done 600 out of 600 | elapsed:   18.1s finished
# GridSearchCV(cv=None, error_score=nan,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, gamma=None,
#                                      gpu_id=None, importance_type='gain',
#                                      interaction_constraints=None,
#                                      learning_rate=None, max_delta_step=None,
#                                      max_depth=4, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      n_estim...
#                                      random_state=42, reg_alpha=None,
#                                      reg_lambda=None, scale_pos_weight=None,
#                                      subsample=None, tree_method=None,
#                                      validate_parameters=False,
#                                      verbosity=None),
#              iid='deprecated', n_jobs=None,
#              param_grid={'gamma': [50, 25, 12, 10, 5, 1],
#                          'learning_rate': [0.1, 0.01, 0.001, 0.0001],
#                          'n_estimator': [10, 100, 1000, 2000, 3000]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %%
# print best parameter after tuning 
print(grid2.best_params_) 
  
# print how our model looks after hyper-parameter tuning 
print(grid2.best_estimator_)
# Out:
# {'gamma': 12, 'learning_rate': 0.1, 'n_estimator': 10}
# XGBClassifier(base_score=0.5, booster=None, colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=12, gpu_id=-1,
#               importance_type='gain', interaction_constraints=None,
#               learning_rate=0.1, max_delta_step=0, max_depth=4,
#               min_child_weight=1, missing=nan, monotone_constraints=None,
#               n_estimator=10, n_estimators=100, n_jobs=0, num_parallel_tree=1,
#               objective='binary:logistic', random_state=42, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method=None,
#               validate_parameters=False, verbosity=None)

# %%
#testing
y_pred = grid2.predict(X_test)

score = accuracy_score(y_test, y_pred)
print("Accuracy of XGBOOST classifier is",score*100,"%")
# Out:
# Accuracy of XGBOOST classifier is 86.88524590163934 %

# %% [markdown]
# # Neural network

# %%
from sklearn.preprocessing import StandardScaler
from keras.utils import to_categorical
from keras.callbacks.callbacks import ModelCheckpoint
from keras.models import Sequential,load_model
from keras.layers import Dense
# Out:
# Using TensorFlow backend.

# %%
scaler = StandardScaler()

scaler = scaler.fit(X_train)

X_trainS = scaler.transform(X_train)
X_testS = scaler.transform(X_test)

y_train = to_categorical(y_train, num_classes = 2)

# %%
# Neural network
model = Sequential()
model.add(Dense(80, input_dim = X_train.shape[1], activation = "relu"))
model.add(Dense(50, activation = "relu"))
model.add(Dense(2, activation = "softmax"))
model.compile(loss ='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])


# best model file path
filepath = "../working/nn.pkl"

# callback 
Callback = [ModelCheckpoint(filepath = filepath,
                          monitor = 'val_loss',
                          verbose=1,
                          save_best_only = True,
                          save_weights_only=False,
                          mode='auto', period=1)]
## 
epochs = 120
batch_size = 64


# training model
history = model.fit(X_trainS, y_train,
                    epochs = epochs,
                    batch_size = batch_size,
                    validation_split=0.1,
                    callbacks = Callback)
# Out:
# Train on 217 samples, validate on 25 samples
# Epoch 1/120
# 217/217 [==============================] - 0s 2ms/step - loss: 0.6381 - accuracy: 0.6728 - val_loss: 0.5622 - val_accuracy: 0.7200
#
# Epoch 00001: val_loss improved from inf to 0.56217, saving model to ../working/nn.pkl
# Epoch 2/120
# 217/217 [==============================] - 0s 51us/step - loss: 0.5640 - accuracy: 0.7742 - val_loss: 0.5044 - val_accuracy: 0.8400
#
# Epoch 00002: val_loss improved from 0.56217 to 0.50441, saving model to ../working/nn.pkl
# Epoch 3/120
# 217/217 [==============================] - 0s 52us/step - loss: 0.5059 - accuracy: 0.8249 - val_loss: 0.4626 - val_accuracy: 0.9200
#
# Epoch 00003: val_loss improved from 0.50441 to 0.46260, saving model to ../working/nn.pkl
# Epoch 4/120
# 217/217 [==============================] - 0s 51us/step - loss: 0.4597 - accuracy: 0.8249 - val_loss: 0.4290 - val_accuracy: 0.8800
#
# Epoch 00004: val_loss improved from 0.46260 to 0.42896, saving model to ../working/nn.pkl
# Epoch 5/120
# 217/217 [==============================] - 0s 51us/step - loss: 0.4261 - accuracy: 0.8295 - val_loss: 0.4019 - val_accuracy: 0.8800
#
# Epoch 00005: val_loss improved from 0.42896 to 0.40187, saving model to ../working/nn.pkl
# Epoch 6/120
# 217/217 [==============================] - 0s 53us/step - loss: 0.3989 - accuracy: 0.8433 - val_loss: 0.3818 - val_accuracy: 0.8800
#
# Epoch 00006: val_loss improved from 0.40187 to 0.38184, saving model to ../working/nn.pkl
# Epoch 7/120
# 217/217 [==============================] - 0s 49us/step - loss: 0.3786 - accuracy: 0.8525 - val_loss: 0.3652 - val_accuracy: 0.8800
#
# Epoch 00007: val_loss improved from 0.38184 to 0.36517, saving model to ../working/nn.pkl
# Epoch 8/120
# 217/217 [==============================] - 0s 55us/step - loss: 0.3619 - accuracy: 0.8618 - val_loss: 0.3542 - val_accuracy: 0.8800
#
# Epoch 00008: val_loss improved from 0.36517 to 0.35422, saving model to ../working/nn.pkl
# Epoch 9/120
# 217/217 [==============================] - 0s 50us/step - loss: 0.3484 - accuracy: 0.8664 - val_loss: 0.3422 - val_accuracy: 0.8800
#
# Epoch 00009: val_loss improved from 0.35422 to 0.34216, saving model to ../working/nn.pkl
# Epoch 10/120
# 217/217 [==============================] - 0s 58us/step - loss: 0.3385 - accuracy: 0.8664 - val_loss: 0.3331 - val_accuracy: 0.8800
#
# Epoch 00010: val_loss improved from 0.34216 to 0.33309, saving model to ../working/nn.pkl
# Epoch 11/120
# 217/217 [==============================] - 0s 58us/step - loss: 0.3283 - accuracy: 0.8710 - val_loss: 0.3289 - val_accuracy: 0.8800
#
# Epoch 00011: val_loss improved from 0.33309 to 0.32888, saving model to ../working/nn.pkl
# Epoch 12/120
# 217/217 [==============================] - 0s 56us/step - loss: 0.3200 - accuracy: 0.8802 - val_loss: 0.3257 - val_accuracy: 0.8800
#
# Epoch 00012: val_loss improved from 0.32888 to 0.32566, saving model to ../working/nn.pkl
# Epoch 13/120
# 217/217 [==============================] - 0s 52us/step - loss: 0.3127 - accuracy: 0.8802 - val_loss: 0.3249 - val_accuracy: 0.8800
#
# Epoch 00013: val_loss improved from 0.32566 to 0.32494, saving model to ../working/nn.pkl
# Epoch 14/120
# 217/217 [==============================] - 0s 54us/step - loss: 0.3059 - accuracy: 0.8894 - val_loss: 0.3280 - val_accuracy: 0.8800
#
# Epoch 00014: val_loss did not improve from 0.32494
# Epoch 15/120
# 217/217 [==============================] - 0s 52us/step - loss: 0.2980 - accuracy: 0.8894 - val_loss: 0.3345 - val_accuracy: 0.8800
#
# Epoch 00015: val_loss did not improve from 0.32494
# Epoch 16/120
# 217/217 [==============================] - 0s 50us/step - loss: 0.2927 - accuracy: 0.8940 - val_loss: 0.3401 - val_accuracy: 0.9200
#
# Epoch 00016: val_loss did not improve from 0.32494
# Epoch 17/120
# 217/217 [==============================] - 0s 49us/step - loss: 0.2866 - accuracy: 0.8986 - val_loss: 0.3431 - val_accuracy: 0.9200
#
# Epoch 00017: val_loss did not improve from 0.32494
# Epoch 18/120
# 217/217 [==============================] - 0s 48us/step - loss: 0.2806 - accuracy: 0.9078 - val_loss: 0.3436 - val_accuracy: 0.8800
#
# Epoch 00018: val_loss did not improve from 0.32494
# Epoch 19/120
# 217/217 [==============================] - 0s 49us/step - loss: 0.2747 - accuracy: 0.9078 - val_loss: 0.3458 - val_accuracy: 0.8800
#
# Epoch 00019: val_loss did not improve from 0.32494
# Epoch 20/120
# 217/217 [==============================] - 0s 48us/step - loss: 0.2690 - accuracy: 0.9032 - val_loss: 0.3454 - val_accuracy: 0.8800
#
# Epoch 00020: val_loss did not improve from 0.32494
# Epoch 21/120
# 217/217 [==============================] - 0s 47us/step - loss: 0.2634 - accuracy: 0.9124 - val_loss: 0.3486 - val_accuracy: 0.8800
#
# Epoch 00021: val_loss did not improve from 0.32494
# Epoch 22/120
# 217/217 [==============================] - 0s 49us/step - loss: 0.2581 - accuracy: 0.9124 - val_loss: 0.3506 - val_accuracy: 0.8800
#
# Epoch 00022: val_loss did not improve from 0.32494
# Epoch 23/120
# 217/217 [==============================] - 0s 46us/step - loss: 0.2526 - accuracy: 0.9124 - val_loss: 0.3499 - val_accuracy: 0.8800
#
# Epoch 00023: val_loss did not improve from 0.32494
# Epoch 24/120
# 217/217 [==============================] - 0s 49us/step - loss: 0.2476 - accuracy: 0.9124 - val_loss: 0.3477 - val_accuracy: 0.8800
#
# Epoch 00024: val_loss did not improve from 0.32494
# Epoch 25/120
# 217/217 [==============================] - 0s 47us/step - loss: 0.2428 - accuracy: 0.9124 - val_loss: 0.3456 - val_accuracy: 0.8800
#
# Epoch 00025: val_loss did not improve from 0.32494
# Epoch 26/120
# 217/217 [==============================] - 0s 50us/step - loss: 0.2376 - accuracy: 0.9124 - val_loss: 0.3451 - val_accuracy: 0.8800
#
# Epoch 00026: val_loss did not improve from 0.32494
# Epoch 27/120
# 217/217 [==============================] - 0s 48us/step - loss: 0.2327 - accuracy: 0.9124 - val_loss: 0.3441 - val_accuracy: 0.8800
#
# Epoch 00027: val_loss did not improve from 0.32494
# Epoch 28/120
# 217/217 [==============================] - 0s 48us/step - loss: 0.2276 - accuracy: 0.9124 - val_loss: 0.3481 - val_accuracy: 0.8800
#
# Epoch 00028: val_loss did not improve from 0.32494
# Epoch 29/120
# 217/217 [==============================] - 0s 49us/step - loss: 0.2229 - accuracy: 0.9171 - val_loss: 0.3513 - val_accuracy: 0.8400
#
# Epoch 00029: val_loss did not improve from 0.32494
# Epoch 30/120
# 217/217 [==============================] - 0s 43us/step - loss: 0.2182 - accuracy: 0.9171 - val_loss: 0.3508 - val_accuracy: 0.8400
#
# Epoch 00030: val_loss did not improve from 0.32494
# Epoch 31/120
# 217/217 [==============================] - 0s 50us/step - loss: 0.2134 - accuracy: 0.9217 - val_loss: 0.3532 - val_accuracy: 0.8400
#
# Epoch 00031: val_loss did not improve from 0.32494
# Epoch 32/120
# 217/217 [==============================] - 0s 54us/step - loss: 0.2091 - accuracy: 0.9217 - val_loss: 0.3541 - val_accuracy: 0.8400
#
# Epoch 00032: val_loss did not improve from 0.32494
# Epoch 33/120
# 217/217 [==============================] - 0s 47us/step - loss: 0.2056 - accuracy: 0.9217 - val_loss: 0.3522 - val_accuracy: 0.8400
#
# Epoch 00033: val_loss did not improve from 0.32494
# Epoch 34/120
# 217/217 [==============================] - 0s 45us/step - loss: 0.2000 - accuracy: 0.9355 - val_loss: 0.3569 - val_accuracy: 0.8400
#
# Epoch 00034: val_loss did not improve from 0.32494
# Epoch 35/120
# 217/217 [==============================] - 0s 50us/step - loss: 0.1948 - accuracy: 0.9401 - val_loss: 0.3573 - val_accuracy: 0.8400
#
# Epoch 00035: val_loss did not improve from 0.32494
# Epoch 36/120
# 217/217 [==============================] - 0s 56us/step - loss: 0.1909 - accuracy: 0.9447 - val_loss: 0.3581 - val_accuracy: 0.8400
#
# Epoch 00036: val_loss did not improve from 0.32494
# Epoch 37/120
# 217/217 [==============================] - 0s 49us/step - loss: 0.1866 - accuracy: 0.9447 - val_loss: 0.3621 - val_accuracy: 0.8000
#
# Epoch 00037: val_loss did not improve from 0.32494
# Epoch 38/120
# 217/217 [==============================] - 0s 50us/step - loss: 0.1821 - accuracy: 0.9447 - val_loss: 0.3644 - val_accuracy: 0.8400
#
# Epoch 00038: val_loss did not improve from 0.32494
# Epoch 39/120
# 217/217 [==============================] - 0s 49us/step - loss: 0.1776 - accuracy: 0.9447 - val_loss: 0.3638 - val_accuracy: 0.8400
#
# Epoch 00039: val_loss did not improve from 0.32494
# Epoch 40/120
# 217/217 [==============================] - 0s 51us/step - loss: 0.1733 - accuracy: 0.9447 - val_loss: 0.3658 - val_accuracy: 0.8400
#
# Epoch 00040: val_loss did not improve from 0.32494
# Epoch 41/120
# 217/217 [==============================] - 0s 51us/step - loss: 0.1691 - accuracy: 0.9447 - val_loss: 0.3752 - val_accuracy: 0.8400
#
# Epoch 00041: val_loss did not improve from 0.32494
# Epoch 42/120
# 217/217 [==============================] - 0s 51us/step - loss: 0.1654 - accuracy: 0.9493 - val_loss: 0.3837 - val_accuracy: 0.8800
#
# Epoch 00042: val_loss did not improve from 0.32494
# Epoch 43/120
# 217/217 [==============================] - 0s 50us/step - loss: 0.1616 - accuracy: 0.9493 - val_loss: 0.3877 - val_accuracy: 0.8400
#
# Epoch 00043: val_loss did not improve from 0.32494
# Epoch 44/120
# 217/217 [==============================] - 0s 49us/step - loss: 0.1578 - accuracy: 0.9539 - val_loss: 0.3964 - val_accuracy: 0.8400
#
# Epoch 00044: val_loss did not improve from 0.32494
# Epoch 45/120
# 217/217 [==============================] - 0s 49us/step - loss: 0.1538 - accuracy: 0.9585 - val_loss: 0.3997 - val_accuracy: 0.8400
#
# Epoch 00045: val_loss did not improve from 0.32494
# Epoch 46/120
# 217/217 [==============================] - 0s 53us/step - loss: 0.1502 - accuracy: 0.9585 - val_loss: 0.4034 - val_accuracy: 0.8400
#
# Epoch 00046: val_loss did not improve from 0.32494
# Epoch 47/120
# 217/217 [==============================] - 0s 48us/step - loss: 0.1459 - accuracy: 0.9585 - val_loss: 0.4037 - val_accuracy: 0.8400
#
# Epoch 00047: val_loss did not improve from 0.32494
# Epoch 48/120
# 217/217 [==============================] - 0s 47us/step - loss: 0.1418 - accuracy: 0.9585 - val_loss: 0.4032 - val_accuracy: 0.8000
#
# Epoch 00048: val_loss did not improve from 0.32494
# Epoch 49/120
# 217/217 [==============================] - 0s 47us/step - loss: 0.1380 - accuracy: 0.9585 - val_loss: 0.4044 - val_accuracy: 0.8000
#
# Epoch 00049: val_loss did not improve from 0.32494
# Epoch 50/120
# 217/217 [==============================] - 0s 47us/step - loss: 0.1344 - accuracy: 0.9631 - val_loss: 0.4086 - val_accuracy: 0.8000
#
# Epoch 00050: val_loss did not improve from 0.32494
# Epoch 51/120
# 217/217 [==============================] - 0s 46us/step - loss: 0.1310 - accuracy: 0.9677 - val_loss: 0.4178 - val_accuracy: 0.7600
#
# Epoch 00051: val_loss did not improve from 0.32494
# Epoch 52/120
# 217/217 [==============================] - 0s 49us/step - loss: 0.1267 - accuracy: 0.9677 - val_loss: 0.4233 - val_accuracy: 0.7600
#
# Epoch 00052: val_loss did not improve from 0.32494
# Epoch 53/120
# 217/217 [==============================] - 0s 48us/step - loss: 0.1231 - accuracy: 0.9677 - val_loss: 0.4297 - val_accuracy: 0.7600
#
# Epoch 00053: val_loss did not improve from 0.32494
# Epoch 54/120
# 217/217 [==============================] - 0s 48us/step - loss: 0.1197 - accuracy: 0.9677 - val_loss: 0.4239 - val_accuracy: 0.7600
#
# Epoch 00054: val_loss did not improve from 0.32494
# Epoch 55/120
# 217/217 [==============================] - 0s 48us/step - loss: 0.1165 - accuracy: 0.9677 - val_loss: 0.4235 - val_accuracy: 0.7600
#
# Epoch 00055: val_loss did not improve from 0.32494
# Epoch 56/120
# 217/217 [==============================] - 0s 51us/step - loss: 0.1124 - accuracy: 0.9677 - val_loss: 0.4337 - val_accuracy: 0.7600
#
# Epoch 00056: val_loss did not improve from 0.32494
# Epoch 57/120
# 217/217 [==============================] - 0s 52us/step - loss: 0.1092 - accuracy: 0.9677 - val_loss: 0.4391 - val_accuracy: 0.7600
#
# Epoch 00057: val_loss did not improve from 0.32494
# Epoch 58/120
# 217/217 [==============================] - 0s 45us/step - loss: 0.1060 - accuracy: 0.9677 - val_loss: 0.4429 - val_accuracy: 0.7600
#
# Epoch 00058: val_loss did not improve from 0.32494
# Epoch 59/120
# 217/217 [==============================] - 0s 46us/step - loss: 0.1029 - accuracy: 0.9677 - val_loss: 0.4441 - val_accuracy: 0.7600
#
# Epoch 00059: val_loss did not improve from 0.32494
# Epoch 60/120
# 217/217 [==============================] - 0s 52us/step - loss: 0.0993 - accuracy: 0.9724 - val_loss: 0.4481 - val_accuracy: 0.7600
#
# Epoch 00060: val_loss did not improve from 0.32494
# Epoch 61/120
# 217/217 [==============================] - 0s 49us/step - loss: 0.0967 - accuracy: 0.9770 - val_loss: 0.4528 - val_accuracy: 0.8000
#
# Epoch 00061: val_loss did not improve from 0.32494
# Epoch 62/120
# 217/217 [==============================] - 0s 48us/step - loss: 0.0935 - accuracy: 0.9816 - val_loss: 0.4591 - val_accuracy: 0.8400
#
# Epoch 00062: val_loss did not improve from 0.32494
# Epoch 63/120
# 217/217 [==============================] - 0s 46us/step - loss: 0.0905 - accuracy: 0.9816 - val_loss: 0.4694 - val_accuracy: 0.8000
#
# Epoch 00063: val_loss did not improve from 0.32494
# Epoch 64/120
# 217/217 [==============================] - 0s 52us/step - loss: 0.0877 - accuracy: 0.9816 - val_loss: 0.4766 - val_accuracy: 0.8000
#
# Epoch 00064: val_loss did not improve from 0.32494
# Epoch 65/120
# 217/217 [==============================] - 0s 51us/step - loss: 0.0848 - accuracy: 0.9816 - val_loss: 0.4816 - val_accuracy: 0.8000
#
# Epoch 00065: val_loss did not improve from 0.32494
# Epoch 66/120
# 217/217 [==============================] - 0s 49us/step - loss: 0.0828 - accuracy: 0.9816 - val_loss: 0.4878 - val_accuracy: 0.7600
#
# Epoch 00066: val_loss did not improve from 0.32494
# Epoch 67/120
# 217/217 [==============================] - 0s 53us/step - loss: 0.0799 - accuracy: 0.9862 - val_loss: 0.4919 - val_accuracy: 0.7600
#
# Epoch 00067: val_loss did not improve from 0.32494
# Epoch 68/120
# 217/217 [==============================] - 0s 49us/step - loss: 0.0774 - accuracy: 0.9908 - val_loss: 0.5001 - val_accuracy: 0.8000
#
# Epoch 00068: val_loss did not improve from 0.32494
# Epoch 69/120
# 217/217 [==============================] - 0s 46us/step - loss: 0.0748 - accuracy: 0.9908 - val_loss: 0.5057 - val_accuracy: 0.8000
#
# Epoch 00069: val_loss did not improve from 0.32494
# Epoch 70/120
# 217/217 [==============================] - 0s 51us/step - loss: 0.0724 - accuracy: 0.9908 - val_loss: 0.5039 - val_accuracy: 0.8000
#
# Epoch 00070: val_loss did not improve from 0.32494
# Epoch 71/120
# 217/217 [==============================] - 0s 54us/step - loss: 0.0704 - accuracy: 0.9908 - val_loss: 0.5076 - val_accuracy: 0.8000
#
# Epoch 00071: val_loss did not improve from 0.32494
# Epoch 72/120
# 217/217 [==============================] - 0s 56us/step - loss: 0.0683 - accuracy: 0.9908 - val_loss: 0.5177 - val_accuracy: 0.8000
#
# Epoch 00072: val_loss did not improve from 0.32494
# Epoch 73/120
# 217/217 [==============================] - 0s 55us/step - loss: 0.0658 - accuracy: 0.9908 - val_loss: 0.5162 - val_accuracy: 0.8000
#
# Epoch 00073: val_loss did not improve from 0.32494
# Epoch 74/120
# 217/217 [==============================] - 0s 55us/step - loss: 0.0637 - accuracy: 0.9908 - val_loss: 0.5148 - val_accuracy: 0.8000
#
# Epoch 00074: val_loss did not improve from 0.32494
# Epoch 75/120
# 217/217 [==============================] - 0s 52us/step - loss: 0.0613 - accuracy: 0.9908 - val_loss: 0.5180 - val_accuracy: 0.8000
#
# Epoch 00075: val_loss did not improve from 0.32494
# Epoch 76/120
# 217/217 [==============================] - 0s 49us/step - loss: 0.0597 - accuracy: 0.9908 - val_loss: 0.5194 - val_accuracy: 0.8000
#
# Epoch 00076: val_loss did not improve from 0.32494
# Epoch 77/120
# 217/217 [==============================] - 0s 50us/step - loss: 0.0579 - accuracy: 0.9908 - val_loss: 0.5271 - val_accuracy: 0.8000
#
# Epoch 00077: val_loss did not improve from 0.32494
# Epoch 78/120
# 217/217 [==============================] - 0s 50us/step - loss: 0.0559 - accuracy: 0.9908 - val_loss: 0.5347 - val_accuracy: 0.8000
#
# Epoch 00078: val_loss did not improve from 0.32494
# Epoch 79/120
# 217/217 [==============================] - 0s 50us/step - loss: 0.0540 - accuracy: 0.9908 - val_loss: 0.5460 - val_accuracy: 0.8000
#
# Epoch 00079: val_loss did not improve from 0.32494
# Epoch 80/120
# 217/217 [==============================] - 0s 53us/step - loss: 0.0524 - accuracy: 0.9954 - val_loss: 0.5592 - val_accuracy: 0.8000
#
# Epoch 00080: val_loss did not improve from 0.32494
# Epoch 81/120
# 217/217 [==============================] - 0s 49us/step - loss: 0.0509 - accuracy: 0.9908 - val_loss: 0.5627 - val_accuracy: 0.8000
#
# Epoch 00081: val_loss did not improve from 0.32494
# Epoch 82/120
# 217/217 [==============================] - 0s 53us/step - loss: 0.0492 - accuracy: 0.9908 - val_loss: 0.5654 - val_accuracy: 0.8000
#
# Epoch 00082: val_loss did not improve from 0.32494
# Epoch 83/120
# 217/217 [==============================] - 0s 47us/step - loss: 0.0481 - accuracy: 0.9954 - val_loss: 0.5713 - val_accuracy: 0.8000
#
# Epoch 00083: val_loss did not improve from 0.32494
# Epoch 84/120
# 217/217 [==============================] - 0s 46us/step - loss: 0.0466 - accuracy: 0.9954 - val_loss: 0.5730 - val_accuracy: 0.8000
#
# Epoch 00084: val_loss did not improve from 0.32494
# Epoch 85/120
# 217/217 [==============================] - 0s 54us/step - loss: 0.0452 - accuracy: 0.9954 - val_loss: 0.5735 - val_accuracy: 0.8000
#
# Epoch 00085: val_loss did not improve from 0.32494
# Epoch 86/120
# 217/217 [==============================] - 0s 49us/step - loss: 0.0437 - accuracy: 0.9954 - val_loss: 0.5722 - val_accuracy: 0.8400
#
# Epoch 00086: val_loss did not improve from 0.32494
# Epoch 87/120
# 217/217 [==============================] - 0s 51us/step - loss: 0.0425 - accuracy: 0.9954 - val_loss: 0.5781 - val_accuracy: 0.8000
#
# Epoch 00087: val_loss did not improve from 0.32494
# Epoch 88/120
# 217/217 [==============================] - 0s 50us/step - loss: 0.0412 - accuracy: 0.9954 - val_loss: 0.5840 - val_accuracy: 0.8000
#
# Epoch 00088: val_loss did not improve from 0.32494
# Epoch 89/120
# 217/217 [==============================] - 0s 52us/step - loss: 0.0401 - accuracy: 0.9954 - val_loss: 0.5943 - val_accuracy: 0.8000
#
# Epoch 00089: val_loss did not improve from 0.32494
# Epoch 90/120
# 217/217 [==============================] - 0s 49us/step - loss: 0.0389 - accuracy: 1.0000 - val_loss: 0.6018 - val_accuracy: 0.8000
#
# Epoch 00090: val_loss did not improve from 0.32494
# Epoch 91/120
# 217/217 [==============================] - 0s 47us/step - loss: 0.0379 - accuracy: 1.0000 - val_loss: 0.6088 - val_accuracy: 0.8000
#
# Epoch 00091: val_loss did not improve from 0.32494
# Epoch 92/120
# 217/217 [==============================] - 0s 50us/step - loss: 0.0369 - accuracy: 1.0000 - val_loss: 0.6145 - val_accuracy: 0.8000
#
# Epoch 00092: val_loss did not improve from 0.32494
# Epoch 93/120
# 217/217 [==============================] - 0s 50us/step - loss: 0.0357 - accuracy: 1.0000 - val_loss: 0.6212 - val_accuracy: 0.8000
#
# Epoch 00093: val_loss did not improve from 0.32494
# Epoch 94/120
# 217/217 [==============================] - 0s 50us/step - loss: 0.0348 - accuracy: 1.0000 - val_loss: 0.6272 - val_accuracy: 0.8000
#
# Epoch 00094: val_loss did not improve from 0.32494
# Epoch 95/120
# 217/217 [==============================] - 0s 51us/step - loss: 0.0340 - accuracy: 1.0000 - val_loss: 0.6325 - val_accuracy: 0.8000
#
# Epoch 00095: val_loss did not improve from 0.32494
# Epoch 96/120
# 217/217 [==============================] - 0s 51us/step - loss: 0.0331 - accuracy: 1.0000 - val_loss: 0.6358 - val_accuracy: 0.8000
#
# Epoch 00096: val_loss did not improve from 0.32494
# Epoch 97/120
# 217/217 [==============================] - 0s 50us/step - loss: 0.0322 - accuracy: 1.0000 - val_loss: 0.6414 - val_accuracy: 0.8000
#
# Epoch 00097: val_loss did not improve from 0.32494
# Epoch 98/120
# 217/217 [==============================] - 0s 47us/step - loss: 0.0315 - accuracy: 1.0000 - val_loss: 0.6481 - val_accuracy: 0.8000
#
# Epoch 00098: val_loss did not improve from 0.32494
# Epoch 99/120
# 217/217 [==============================] - 0s 49us/step - loss: 0.0306 - accuracy: 1.0000 - val_loss: 0.6559 - val_accuracy: 0.8000
#
# Epoch 00099: val_loss did not improve from 0.32494
# Epoch 100/120
# 217/217 [==============================] - 0s 48us/step - loss: 0.0299 - accuracy: 1.0000 - val_loss: 0.6663 - val_accuracy: 0.8000
#
# Epoch 00100: val_loss did not improve from 0.32494
# Epoch 101/120
# 217/217 [==============================] - 0s 46us/step - loss: 0.0288 - accuracy: 1.0000 - val_loss: 0.6715 - val_accuracy: 0.8000
#
# Epoch 00101: val_loss did not improve from 0.32494
# Epoch 102/120
# 217/217 [==============================] - 0s 49us/step - loss: 0.0282 - accuracy: 1.0000 - val_loss: 0.6772 - val_accuracy: 0.8000
#
# Epoch 00102: val_loss did not improve from 0.32494
# Epoch 103/120
# 217/217 [==============================] - 0s 51us/step - loss: 0.0276 - accuracy: 1.0000 - val_loss: 0.6761 - val_accuracy: 0.8000
#
# Epoch 00103: val_loss did not improve from 0.32494
# Epoch 104/120
# 217/217 [==============================] - 0s 50us/step - loss: 0.0267 - accuracy: 1.0000 - val_loss: 0.6736 - val_accuracy: 0.8000
#
# Epoch 00104: val_loss did not improve from 0.32494
# Epoch 105/120
# 217/217 [==============================] - 0s 50us/step - loss: 0.0259 - accuracy: 1.0000 - val_loss: 0.6760 - val_accuracy: 0.7600
#
# Epoch 00105: val_loss did not improve from 0.32494
# Epoch 106/120
# 217/217 [==============================] - 0s 48us/step - loss: 0.0253 - accuracy: 1.0000 - val_loss: 0.6836 - val_accuracy: 0.7600
#
# Epoch 00106: val_loss did not improve from 0.32494
# Epoch 107/120
# 217/217 [==============================] - 0s 48us/step - loss: 0.0248 - accuracy: 1.0000 - val_loss: 0.6919 - val_accuracy: 0.7600
#
# Epoch 00107: val_loss did not improve from 0.32494
# Epoch 108/120
# 217/217 [==============================] - 0s 47us/step - loss: 0.0242 - accuracy: 1.0000 - val_loss: 0.7044 - val_accuracy: 0.7600
#
# Epoch 00108: val_loss did not improve from 0.32494
# Epoch 109/120
# 217/217 [==============================] - 0s 46us/step - loss: 0.0233 - accuracy: 1.0000 - val_loss: 0.7173 - val_accuracy: 0.7600
#
# Epoch 00109: val_loss did not improve from 0.32494
# Epoch 110/120
# 217/217 [==============================] - 0s 50us/step - loss: 0.0230 - accuracy: 1.0000 - val_loss: 0.7222 - val_accuracy: 0.7600
#
# Epoch 00110: val_loss did not improve from 0.32494
# Epoch 111/120
# 217/217 [==============================] - 0s 54us/step - loss: 0.0226 - accuracy: 1.0000 - val_loss: 0.7180 - val_accuracy: 0.7600
#
# Epoch 00111: val_loss did not improve from 0.32494
# Epoch 112/120
# 217/217 [==============================] - 0s 54us/step - loss: 0.0216 - accuracy: 1.0000 - val_loss: 0.7199 - val_accuracy: 0.7600
#
# Epoch 00112: val_loss did not improve from 0.32494
# Epoch 113/120
# 217/217 [==============================] - 0s 47us/step - loss: 0.0213 - accuracy: 1.0000 - val_loss: 0.7213 - val_accuracy: 0.7600
#
# Epoch 00113: val_loss did not improve from 0.32494
# Epoch 114/120
# 217/217 [==============================] - 0s 49us/step - loss: 0.0205 - accuracy: 1.0000 - val_loss: 0.7275 - val_accuracy: 0.7600
#
# Epoch 00114: val_loss did not improve from 0.32494
# Epoch 115/120
# 217/217 [==============================] - 0s 50us/step - loss: 0.0202 - accuracy: 1.0000 - val_loss: 0.7293 - val_accuracy: 0.7600
#
# Epoch 00115: val_loss did not improve from 0.32494
# Epoch 116/120
# 217/217 [==============================] - 0s 47us/step - loss: 0.0198 - accuracy: 1.0000 - val_loss: 0.7266 - val_accuracy: 0.7600
#
# Epoch 00116: val_loss did not improve from 0.32494
# Epoch 117/120
# 217/217 [==============================] - 0s 47us/step - loss: 0.0193 - accuracy: 1.0000 - val_loss: 0.7278 - val_accuracy: 0.7600
#
# Epoch 00117: val_loss did not improve from 0.32494
# Epoch 118/120
# 217/217 [==============================] - 0s 47us/step - loss: 0.0187 - accuracy: 1.0000 - val_loss: 0.7356 - val_accuracy: 0.7600
#
# Epoch 00118: val_loss did not improve from 0.32494
# Epoch 119/120
# 217/217 [==============================] - 0s 50us/step - loss: 0.0181 - accuracy: 1.0000 - val_loss: 0.7425 - val_accuracy: 0.7600
#
# Epoch 00119: val_loss did not improve from 0.32494
# Epoch 120/120
# 217/217 [==============================] - 0s 44us/step - loss: 0.0178 - accuracy: 1.0000 - val_loss: 0.7541 - val_accuracy: 0.7600
#
# Epoch 00120: val_loss did not improve from 0.32494

# %%
# plotting  accuracy and losses
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = [*range(epochs)]

plt.plot(epochs,acc, label = "train_acc")
plt.plot(epochs,val_acc, label = "val_acc")
plt.legend()

plt.show()
plt.plot(epochs,loss, label = "train_loss")
plt.plot(epochs,val_loss, label = "test_loss")
plt.legend()
plt.show()

# %%
model = load_model(filepath)

y_pred = np.argmax(model.predict(X_testS),axis=1)

print(f"Accuracy of nn is: {accuracy_score(y_pred, y_test)*100}%")
# Out:
# Accuracy of nn is: 88.52459016393442%
